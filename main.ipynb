# %%
import pandas as pd

lore_dict = {
  "lorebookVersion": 4,
  "entries": [
    {
      "text": "The Roman Empire burned in the year 476. The emperor Valens was killed by his own soldiers, and a civil war broke out among those who wished to succeed him. After years of fighting between rival factions, the empire fell apart into separate kingdoms - most notably that of Constantinople (now known as Istanbul). This marked the end of an era which had lasted for nearly two thousand years.",
      "contextConfig": {
        "prefix": "",
        "suffix": "\n",
        "tokenBudget": 2048,
        "reservedTokens": 0,
        "budgetPriority": 400,
        "trimDirection": "trimBottom",
        "insertionType": "newline",
        "maximumTrimType": "sentence",
        "insertionPosition": -1
      },
      "lastUpdatedAt": 1666044123984,
      "displayName": "Rome Burning",
      "id": "642723d1-a4a1-47a3-a63f-d36aee33de1b",
      "keys": [
        "Rome",
        "Emperor",
        "476 AD"
      ],
      "searchRange": 1000,
      "enabled": true,
      "forceActivation": false,
      "keyRelative": false,
      "nonStoryActivatable": false,
      "category": "",
      "loreBiasGroups": [
        {
          "phrases": [],
          "ensureSequenceFinish": false,
          "generateOnce": true,
          "bias": 0,
          "enabled": true,
          "whenInactive": false
        }
      ]
    }
  ],
  "settings": {
    "orderByKeyLocations": false
  },
  "categories": []
}

# %%
## The goal: generate a lorebook dict from a list of text entries.
# list of text entries
entries = [
    'Testing 1',
    'Testing 2',
    'Testing 3'
]
entry_names = [
    'Test 1',
    'Test 2',
    'Test 3'
]

# %%
# create a new dict with the same structure as the lorebook dict above (lore_dict) using the entries list to populate the text key of each entry
# settings, categories are the same as in the example lore_dict

# the outline of every new entry should be as shown below
# {text, contextConfig, lastUpdatedAt, displayName, id, keys, searchRange, enabled, forceActivation, keyRelative, nonStoryActivatable, category, loreBiasGroups}
# the text key should be populated with the text from the entries list
# the displayName key should be populated with the word from the entry_names list
# the id key should be populated with a unique id for each entry
# the keys key should be populated with a list of words from the entry_names list that are not stop words and are unique to that entry
# the loreBiasGroups key should be populated with the same structure as the loreBiasGroups key in the example lore_dict

# the goal is to create a new dict that can be saved as a json file and used as a lorebook dict
import json
# create a new dict with the same structure as the lorebook dict above (lore_dict) using the entries list to populate the text key of each entry
# settings, categories are the same as in the example lore_dict
new_dict = {
    "lorebookVersion": 4,
    "entries": [
        {
            "text": entries[0],
            "contextConfig": {
                "prefix": "",
                "suffix": "\n",
                "tokenBudget": 2048,
                "reservedTokens": 0,
                "budgetPriority": 400,
                "trimDirection": "trimBottom",
                "insertionType": "newline",
                "maximumTrimType": "sentence",
                "insertionPosition": -1
            },
            "lastUpdatedAt": 1666044123984,
            "displayName": entry_names[0],
            "id": "642723d1-a4a1-47a3-a63f-d36aee33de1b",
            "keys": [
                entry_names[0]
            ],  
            "searchRange": 1000,
            "enabled": True,
            "forceActivation": False,
            "keyRelative": False,
            "nonStoryActivatable": False,
            "category": "",
            "loreBiasGroups": [
                {
                    "phrases": [],
                    "ensureSequenceFinish": False,
                    "generateOnce": True,
                    "bias": 0,
                    "enabled": True,
                    "whenInactive": False
                }
            ]
        },
        {
            "text": entries[1]
        },
        {
            "text": entries[2]
        }
    ],
    "settings": {
        "orderByKeyLocations": False
    },
    "categories": []
}
