# %%
import pandas as pd
import json
# lore_dict = {
#   "lorebookVersion": 4,
#   "entries": [
#     {
#       "text": "The Roman Empire burned in the year 476. The emperor Valens was killed by his own soldiers, and a civil war broke out among those who wished to succeed him. After years of fighting between rival factions, the empire fell apart into separate kingdoms - most notably that of Constantinople (now known as Istanbul). This marked the end of an era which had lasted for nearly two thousand years.",
#       "contextConfig": {
#         "prefix": "",
#         "suffix": "\n",
#         "tokenBudget": 2048,
#         "reservedTokens": 0,
#         "budgetPriority": 400,
#         "trimDirection": "trimBottom",
#         "insertionType": "newline",
#         "maximumTrimType": "sentence",
#         "insertionPosition": -1
#       },
#       "lastUpdatedAt": 1666044123984,
#       "displayName": "Rome Burning",
#       "id": "642723d1-a4a1-47a3-a63f-d36aee33de1b",
#       "keys": [
#         "Rome",
#         "Emperor",
#         "476 AD"
#       ],
#       "searchRange": 1000,
#       "enabled": true,
#       "forceActivation": false,
#       "keyRelative": false,
#       "nonStoryActivatable": false,
#       "category": "",
#       "loreBiasGroups": [
#         {
#           "phrases": [],
#           "ensureSequenceFinish": false,
#           "generateOnce": true,
#           "bias": 0,
#           "enabled": true,
#           "whenInactive": false
#         }
#       ]
#     }
#   ],
#   "settings": {
#     "orderByKeyLocations": false
#   },
#   "categories": []
# }

# %%
# get all links on each of the entity pages
from tqdm import tqdm
import pandas as pd
import wikipedia
# check those article pages for length (if they are too short, skip them)
# if they are long enough, and are not already in the list, add them to the list
list_of_names = pd.read_csv('characters.csv')
print(type(list_of_names))
list_of_names = list_of_names['Name'].tolist()
entries = []
entry_names = []
for name in tqdm(list_of_names):
    if name != '':
        try:
            entry = wikipedia.search(name)[0] # get the first result from wikipedia, which is usually the most relevant
            page = wikipedia.page(entry)
            entry = page.content
            links = page.links
            print(f'Adding {name} to entries')
            for link in links:
                # for every 2nd degree page
                try:
                    page = wikipedia.page(link)
                    # print('category: ', page.categories)
                    if link not in entry_names and page.content != '' and len(page.content) > 5000 and (page.content.find('Born') != -1): # if the page is long enough and not already in the list, add it
                        entries.append(page.content)
                        entry_names.append(link)
                        print(f' ==> Adding {link} to the list of entries')
                except:
                    pass
        except Exception as e:
            print(e)
            continue
    df = pd.DataFrame(entry_names)
    df.to_csv('entry_names.csv', index=False) # save the list of entries

# save entry_names to a csv
df = pd.DataFrame(entry_names)
df.to_csv('entry_names.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   0%|          | 0/83 [00:00<?, ?it/s]
# Adding Victorian Era to entries
# category:  ['1929 in New York City', '1929 in economics', '1929 in international relations', 'All articles containing potentially dated statements', 'All articles with unsourced statements', 'Articles containing potentially dated statements from August 2022', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NARA identifiers', 'Articles with short description', 'Articles with unsourced statements from January 2019', 'Articles with unsourced statements from October 2019', 'Articles with unsourced statements from October 2020', 'CS1 French-language sources (fr)', 'CS1 maint: bot: original URL status unknown', 'Commons category link is on Wikidata', 'Economic bubbles', 'Great Depression in the United States', 'October 1929 events', 'Pages with missing ISBNs', 'Roaring Twenties', 'September 1929 events', 'Short description matches Wikidata', 'Stock market crashes', 'Use mdy dates from March 2021', 'Webarchive template wayback links', 'Wikipedia articles needing clarification from March 2020', 'Wikipedia articles needing page number citations from October 2021']
# category:  ['1987 establishments in England', 'All stub articles', 'Annual events in London', 'Art fairs', 'Arts in London', 'British art', 'June events', 'London stubs', 'Recurring events established in 1987', 'Royal College of Art', 'September events', 'Use dmy dates from August 2019', 'Visual arts stubs']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['2009 art awards', '2009 awards in the United Kingdom', 'Turner Prize', 'Use British English from August 2015', 'Use dmy dates from August 2015', 'Webarchive template wayback links']
#  ==> Adding 2009 Turner Prize to the list of entries
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['1984 establishments in the United Kingdom', '1984 in art', 'All articles with dead external links', 'All articles with specifically marked weasel-worded phrases', 'All articles with unsourced statements', 'Annual events in the United Kingdom', 'Articles with GND identifiers', 'Articles with LNB identifiers', 'Articles with dead external links from January 2017', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from January 2019', 'Articles with unsourced statements from July 2021', 'Awards established in 1984', 'Awards with age limits', 'British art awards', 'British contemporary art', 'Commons category link from Wikidata', 'Contemporary art awards', 'Culture in London', 'Early career awards', 'EngvarB from May 2016', 'Festivals in London', 'Short description matches Wikidata', 'Tate galleries', 'Turner Prize', 'Turner Prize winners', 'Use dmy dates from May 2016', 'Webarchive template wayback links']
# category:  ['All articles needing additional references', 'Articles needing additional references from July 2022', 'Articles with short description', 'Articles with specifically marked weasel-worded phrases from October 2022', 'Commons category link from Wikidata', 'Coordinates on Wikidata', 'Ernő Goldfinger buildings', 'Grade II* listed houses in London', 'Historic house museums in London', 'Houses completed in 1938', 'Houses in Hampstead', 'Modernist architecture in London', 'Museums in the London Borough of Camden', 'National Trust properties in London', 'Short description is different from Wikidata', 'Use British English from January 2014', 'Use dmy dates from January 2014', 'Wikipedia articles needing clarification from September 2022']
# category:  ['Articles with short description', 'Coordinates on Wikidata', 'Georgian architecture in London', 'Historic house museums in London', 'Houses in the London Borough of Lambeth', 'Museums established in 2013', 'Museums in the London Borough of Lambeth', 'National Trust properties in London', 'Short description is different from Wikidata', 'Use British English from August 2015', 'Use dmy dates from August 2015', 'Visionary environments', 'Webarchive template wayback links']
# category:  ['1851 births', '1942 deaths', '19th-century English architects', '20th-century English architects', 'Art Nouveau designers', 'Art Nouveau illustrators', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with Internet Archive links', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with short description', 'English designers', 'English illustrators', 'People educated at Felsted School', 'Short description is different from Wikidata', 'Use British English from April 2017', 'Use dmy dates from April 2017']
# category:  ['1731 paintings', '18th-century engravings', 'All articles needing additional references', 'All articles with unsourced statements', 'Articles containing French-language text', 'Articles needing additional references from July 2018', 'Articles with short description', 'Articles with unsourced statements from January 2013', 'Commons category link is on Wikidata', 'EngvarB from September 2013', 'IMDb ID not in Wikidata', 'Lost paintings', 'Painting series', 'Paintings by William Hogarth', 'Prints by William Hogarth', 'Prostitution in paintings', 'Short description matches Wikidata', 'Use dmy dates from September 2013', 'Works about prostitution in the United Kingdom']
# category:  ['1766 paintings', 'AC with 0 elements', 'Articles with short description', 'Collections of Derby Museum and Art Gallery', 'EngvarB from September 2013', 'Historical scientific instruments', 'Paintings by Joseph Wright of Derby', 'Paintings of children', 'Science in art', 'Short description matches Wikidata', 'Use dmy dates from November 2020']
# category:  ['1730s paintings', 'Articles with GND identifiers', 'Articles with LCCN identifiers', 'Articles with VIAF identifiers', 'Articles with WorldCat-VIAF identifiers', 'Articles with short description', "Collection of Sir John Soane's Museum", 'Commons category link is on Wikidata', 'English art', 'EngvarB from September 2013', 'Paintings by William Hogarth', 'Paintings in London', 'Prostitution in paintings', 'Short description matches Wikidata', 'Use dmy dates from September 2013', 'Works about prostitution in the United Kingdom']
# category:  ['Abstract art', 'Abstract expressionism', 'All articles with bare URLs for citations', 'All articles with unsourced statements', 'American art', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with GND identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NDL identifiers', 'Articles with NKC identifiers', 'Articles with bare URLs for citations from May 2022', 'Articles with short description', 'Articles with unsourced statements from February 2019', 'Avant-garde art', 'CS1 errors: generic name', 'Commons category link is on Wikidata', 'Congress for Cultural Freedom', 'Contemporary art movements', 'Modern art', 'Pages using div col with small parameter', 'Short description matches Wikidata', 'Webarchive template wayback links']
# category:  ['Abstract art', 'Abstract expressionism', 'All articles with bare URLs for citations', 'All articles with unsourced statements', 'American art', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with GND identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NDL identifiers', 'Articles with NKC identifiers', 'Articles with bare URLs for citations from May 2022', 'Articles with short description', 'Articles with unsourced statements from February 2019', 'Avant-garde art', 'CS1 errors: generic name', 'Commons category link is on Wikidata', 'Congress for Cultural Freedom', 'Contemporary art movements', 'Modern art', 'Pages using div col with small parameter', 'Short description matches Wikidata', 'Webarchive template wayback links']
# category:  ['19th century in art', 'Academic art', 'All articles with unsourced statements', 'Art movements', 'Articles using infobox templates with no data rows', 'Articles with IEU identifiers', 'Articles with short description', 'Articles with unsourced statements from June 2009', 'Commons category link is on Wikidata', 'Short description is different from Wikidata', 'Use dmy dates from January 2020']
# category:  ['Academic terminology', 'Academies', 'All articles that may contain original research', 'All articles with unsourced statements', 'All articles with vague or ambiguous time', 'Articles that may contain original research from May 2018', 'Articles with EMU identifiers', 'Articles with GND identifiers', 'Articles with short description', 'Articles with unsourced statements from February 2008', 'Articles with unsourced statements from July 2007', 'Articles with unsourced statements from June 2009', 'Articles with unsourced statements from May 2021', 'CS1 German-language sources (de)', 'Pages using Sister project links with default search', 'Plato', 'School types', 'Short description matches Wikidata', 'Vague or ambiguous geographic scope from May 2021', 'Vague or ambiguous time from May 2021', 'Webarchive template other archives', 'Webarchive template wayback links']
# category:  ['Articles containing Welsh-language text', 'Articles with short description', 'CS1 maint: archived copy as title', 'Geography of the United Kingdom', 'Government of the United Kingdom', 'Lists of subdivisions of the United Kingdom', 'Short description matches Wikidata', 'Types of subdivision in the United Kingdom', 'United Kingdom by country', 'Use British English from May 2020']
# category:  ['Articles containing Welsh-language text', 'Articles with short description', 'CS1 maint: archived copy as title', 'Geography of the United Kingdom', 'Government of the United Kingdom', 'Lists of subdivisions of the United Kingdom', 'Short description matches Wikidata', 'Types of subdivision in the United Kingdom', 'United Kingdom by country', 'Use British English from May 2020']
# category:  ['Aesthetics', 'All articles with unsourced statements', 'Art movements', 'Articles with GND identifiers', 'Articles with NDL identifiers', 'Articles with short description', 'Articles with unsourced statements from March 2011', 'Commons link from Wikidata', 'Concepts in aesthetics', 'Concepts in epistemology', 'Culture in Oxford', 'Human appearance', 'Modern art', 'Short description matches Wikidata', 'Symbolism (arts)', 'Use dmy dates from April 2022', 'Victorian poetry']
# category:  ['2008 in economics', 'All Wikipedia neutral point of view disputes', 'All articles with unsourced statements', 'Articles with short description', 'Articles with unsourced statements from October 2021', 'CS1 errors: missing periodical', 'CS1 maint: url-status', 'Economic history of the United Kingdom', 'Great Recession in the United Kingdom', 'Housing in the United Kingdom', 'Inflation in the United Kingdom', 'Short description matches Wikidata', 'Wikipedia neutral point of view disputes from January 2018']
# category:  ['Agriculture in the United Kingdom', 'All articles with incomplete citations', 'Articles with incomplete citations from November 2020', 'Articles with short description', 'Commons category link is on Wikidata', 'Short description is different from Wikidata', 'Use British English from January 2015', 'Use dmy dates from June 2020', 'Webarchive template archiveis links', 'Webarchive template wayback links']
# category:  ['1928 births', '2021 deaths', '20th-century British male writers', '20th-century British non-fiction writers', '21st-century British non-fiction writers', '21st-century English male writers', 'All articles needing additional references', 'Alumni of Downing College, Cambridge', 'Alumni of the Courtauld Institute of Art', 'Articles needing additional references from March 2021', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NKC identifiers', 'Articles with NLK identifiers', 'Articles with NTA identifiers', 'Articles with PLWABN identifiers', 'Articles with SUDOC identifiers', 'Articles with TePapa identifiers', 'Articles with Trove identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'British art critics', 'British curators', 'Commanders of the Order of the British Empire', 'Directors of the Tate galleries', 'English art historians', 'Knights Bachelor', 'Pages containing London Gazette template with parameter supp set to y', 'People educated at University College School', 'People from Finchley', 'Short description is different from Wikidata', 'Use British English from August 2015', 'Use dmy dates from March 2021']
# category:  ['11th Hussars officers', '1819 births', '1861 deaths', '19th-century British people', 'AC with 30 elements', 'Albert, Prince Consort', 'Articles containing German-language text', 'Articles with BIBSYS identifiers', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with CANTICN identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ICCU identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with LNB identifiers', 'Articles with MusicBrainz identifiers', 'Articles with NARA identifiers', 'Articles with NGV identifiers', 'Articles with NKC identifiers', 'Articles with NLA identifiers', 'Articles with NTA identifiers', 'Articles with PLWABN identifiers', 'Articles with Project Gutenberg links', 'Articles with RISM identifiers', 'Articles with RKDartists identifiers', 'Articles with SELIBR identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with TePapa identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with VcBA identifiers', 'Articles with WORLDCATID identifiers', 'Articles with multiple identifiers', 'Articles with short description', 'Bailiffs Grand Cross of Honour and Devotion of the Sovereign Military Order of Malta', 'British Protestants', 'British field marshals', 'British royal consorts', 'CS1: Julian–Gregorian uncertainty', 'CS1: abbreviated year range', 'CS1 Danish-language sources (da)', 'CS1 French-language sources (fr)', 'CS1 German-language sources (de)', 'CS1 Italian-language sources (it)', 'CS1 Japanese-language sources (ja)', 'CS1 Portuguese-language sources (pt)', 'Chancellors of the University of Cambridge', 'Commons category link is on Wikidata', 'Featured articles', 'German Protestants', 'German emigrants to the United Kingdom', "Grand Croix of the Légion d'honneur", 'Grand Crosses of the Order of Aviz', 'Grand Crosses of the Order of Christ (Portugal)', 'Grand Crosses of the Order of Saint James of the Sword', 'Grand Crosses of the Order of Saint Stephen of Hungary', 'Great Masters of the Order of the Bath', 'Grenadier Guards officers', 'Honorary Fellows of the Royal Society of Edinburgh', 'House of Saxe-Coburg and Gotha (United Kingdom)', 'Knights Companion of the Order of the Star of India', 'Knights Grand Cross of the Order of St Michael and St George', 'Knights Grand Cross of the Order of the Bath', 'Knights of St Patrick', 'Knights of the Garter', 'Knights of the Golden Fleece of Spain', 'Knights of the Thistle', 'Members of Trinity House', 'Members of the Privy Council of the United Kingdom', 'Pages containing links to subscription-only content', 'People from Coburg', 'Presidents of the British Science Association', 'Presidents of the Zoological Society of London', 'Princes of Saxe-Coburg and Gotha', 'Princes of the United Kingdom', 'Queen Victoria', 'Recipients of the Order of St. Anna, 1st class', 'Recipients of the Order of the Medjidie, 1st class', 'Recipients of the Order of the Netherlands Lion', 'Recipients of the Order of the Tower and Sword', 'Recipients of the Order of the White Eagle (Russia)', 'Royal reburials', 'Scots Guards officers', 'Short description is different from Wikidata', 'University of Bonn alumni', 'Use British English from April 2011', 'Use dmy dates from February 2020', 'Webarchive template wayback links', 'Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference']
# category:  ['1841 births', '1893 deaths', '19th-century English male artists', '19th-century English painters', 'Academic art', 'Articles incorporating Cite DNB template', 'Articles incorporating DNB text with Wikisource reference', 'Articles with AGSA identifiers', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NKC identifiers', 'Articles with NTA identifiers', 'Articles with PLWABN identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with VcBA identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', "Artists' Rifles soldiers", 'Artists from York', 'Burials at Highgate Cemetery', 'Commons category link is on Wikidata', 'English male painters', 'EngvarB from September 2013', "People educated at Archbishop Holgate's School", 'Short description is different from Wikidata', 'Use dmy dates from September 2013']
# category:  ['1717 births', '1786 deaths', '18th-century English painters', 'Articles incorporating Cite DNB template', 'Articles incorporating DNB text with Wikisource reference', 'Articles with BNF identifiers', 'Articles with DSI identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NTA identifiers', 'Articles with RKDartists identifiers', 'Articles with SELIBR identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with short description', 'British watercolourists', 'Commons category link from Wikidata', 'English male painters', 'Landscape artists', 'Short description is different from Wikidata', 'Use dmy dates from October 2019']
# category:  ['1878 births', '1959 deaths', '19th-century English male artists', '19th-century English painters', '20th-century English male artists', '20th-century English painters', 'All articles containing potentially dated statements', 'All articles with unsourced statements', 'Alumni of Norwich University of the Arts', 'Articles containing potentially dated statements from 2007', 'Articles with AAG identifiers', 'Articles with AGSA identifiers', 'Articles with BNF identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with NKC identifiers', 'Articles with NLA identifiers', 'Articles with NTA identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with TePapa identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with multiple identifiers', 'Articles with short description', 'Articles with unsourced statements from September 2017', 'British war artists', "Burials at St Paul's Cathedral", 'Commons category link is on Wikidata', 'English male painters', 'Equine artists', 'Knights Bachelor', 'Knights Commander of the Royal Victorian Order', 'Lamorna Art colony', 'Members of the Royal Institute of Painters in Water Colours', 'Newlyn School of Artists', 'Olympic competitors in art competitions', 'Pages containing London Gazette template with parameter supp set to y', 'Pages using Template:Post-nominals with customized linking', 'Pages using cite ODNB with id parameter', 'People educated at Framlingham College', 'People from Dedham, Essex', 'People from Mid Suffolk District', 'People of the Victorian era', 'Royal Academicians', 'Short description is different from Wikidata', 'Use dmy dates from November 2019', 'Webarchive template wayback links', 'Wikipedia articles incorporating a citation from the ODNB', 'World War I artists']
# category:  ['1839 births', '1899 deaths', '19th-century English painters', '19th-century French painters', 'ACArt with 16 suppressed elements', 'Alfred Sisley', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with GND identifiers', 'Articles with KULTURNAV identifiers', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with NLA identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'Articles with suppressed authority control identifiers', 'Artists from Paris', 'British Impressionist painters', 'British alumni of the École des Beaux-Arts', 'CS1 French-language sources (fr)', 'CS1 maint: bot: original URL status unknown', 'CS1 maint: url-status', 'Commons category link from Wikidata', 'Deaths from throat cancer', 'Deaths in France', 'English male painters', 'French Impressionist painters', 'French male painters', 'French people of English descent', 'Short description is different from Wikidata', 'Use dmy dates from November 2015']
# category:  ['1713 births', '1784 deaths', '18th-century Scottish painters', 'Articles needing more viewpoints from January 2020', 'Articles with AAG identifiers', 'Articles with AGSA identifiers', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with NLA identifiers', 'Articles with NTA identifiers', 'Articles with RKDartists identifiers', 'Articles with SELIBR identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with multiple identifiers', 'Articles with short description', 'Artists from Edinburgh', 'CS1: Julian–Gregorian uncertainty', 'CS1 Turkish-language sources (tr)', 'Commons category link is on Wikidata', 'People of the Scottish Enlightenment', 'Principal Painters in Ordinary', 'Scottish male painters', 'Scottish portrait painters', 'Short description is different from Wikidata', 'Use British English from September 2017', 'Use dmy dates from September 2017', 'Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference', 'Wikipedia articles incorporating text from the 1911 Encyclopædia Britannica']
# category:  ['1937 births', 'All articles with unsourced statements', 'Alumni of Middlesex University', 'Articles with AAG identifiers', 'Articles with AGSA identifiers', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with NKC identifiers', 'Articles with NTA identifiers', 'Articles with PIC identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with TePapa identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'Articles with unsourced statements from August 2015', 'British contemporary artists', 'British erotic artists', 'British male sculptors', 'British pop artists', 'British sculptors', 'CS1 Italian-language sources (it)', 'Commons category link is on Wikidata', 'EngvarB from January 2020', 'Living people', 'Modern sculptors', 'People educated at Ealing County Grammar School for Boys', 'People from Ealing', 'Royal Academicians', 'Short description is different from Wikidata', 'Use dmy dates from January 2020']
# category:  ['1882 births', '1966 deaths', '20th-century American photographers', '20th-century British photographers', 'American emigrants to England', 'American emigrants to Wales', 'American portrait photographers', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with CINII identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with Internet Archive links', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with MusicBrainz identifiers', 'Articles with NGV identifiers', 'Articles with NKC identifiers', 'Articles with NLA identifiers', 'Articles with NTA identifiers', 'Articles with PIC identifiers', 'Articles with Project Gutenberg links', 'Articles with RKDartists identifiers', 'Articles with SELIBR identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with TePapa identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'Artists from Boston', 'British portrait photographers', 'Commons category link is on Wikidata', 'Naturalised citizens of the United Kingdom', 'Photographers from Massachusetts', 'Pictorialists', 'Short description matches Wikidata', 'Use dmy dates from April 2022']
# category:  ['1768 paintings', 'Articles with short description', 'Birds in art', 'Collections of the National Gallery, London', 'Commons category link is on Wikidata', 'EngvarB from September 2013', 'Featured articles', 'Historical scientific instruments', 'Paintings by Joseph Wright of Derby', 'Physics experiments', 'Science in art', 'Short description is different from Wikidata', 'Use dmy dates from September 2013']
# category:  ['1973 sculptures', 'All articles with dead external links', 'Articles with dead external links from January 2022', 'Articles with dead external links from July 2021', 'Conceptual art', 'Contemporary works of art', 'Modernist sculpture', 'Water in art', 'Webarchive template wayback links', 'Works by Michael Craig-Martin']
# category:  ['19th-century art groups', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with short description', 'British art', 'English artist groups and collectives', 'Romantic art movements', 'Short description matches Wikidata', 'Use dmy dates from April 2022']
# category:  ['1998 establishments in England', '1998 sculptures', 'Articles with short description', 'Buildings and structures completed in 1998', 'Buildings and structures in Gateshead', 'Colossal statues in the United Kingdom', 'Commons category link is on Wikidata', 'Coordinates on Wikidata', 'Culture in Tyne and Wear', 'Good articles', 'Northern England', 'Outdoor sculptures in England', 'Ove Arup buildings and structures', 'Sculptures by Antony Gormley', 'Sculptures of angels', 'Short description is different from Wikidata', 'Statues in England', 'Steel sculptures in England', 'Tourist attractions in Tyne and Wear', 'Use British English from December 2015', 'Use dmy dates from September 2013', 'Weathering steel']
# category:  ['Anglo-Saxon art', 'Articles with BNF identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with short description', 'Commons category link is on Wikidata', 'English art', 'EngvarB from November 2013', 'Medieval art', 'Short description is different from Wikidata', 'Use dmy dates from November 2013', 'Webarchive template wayback links']
# category:  ['1904 births', '1990 deaths', '20th-century LGBT people', 'All articles with unsourced statements', 'Articles with BIBSYS identifiers', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with MusicBrainz identifiers', 'Articles with NGV identifiers', 'Articles with NLA identifiers', 'Articles with NTA identifiers', 'Articles with PIC identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with unsourced statements from August 2021', 'British set decorators', 'British surrealist artists', 'EngvarB from April 2015', 'Gay artists', 'LGBT artists from the United Kingdom', 'People educated at Monmouth School', 'People from Abertillery', 'People from Newbridge, Caerphilly', 'People prosecuted under anti-homosexuality laws', 'Use dmy dates from April 2015', 'Welsh people of Scottish descent', 'Welsh photographers']
# category:  ['1954 births', '20th-century British sculptors', '20th-century Indian sculptors', '20th-century male artists', '21st-century British sculptors', '21st-century Indian sculptors', '21st-century male artists', 'AC with 26 elements', 'Academics of the University of Wolverhampton', 'All articles containing potentially dated statements', 'Alumni of Chelsea College of Arts', 'Alumni of Middlesex University', 'Articles containing potentially dated statements from June 2008', 'Articles with AAG identifiers', 'Articles with BIBSYS identifiers', 'Articles with BNE identifiers', 'Articles with BNF identifiers', 'Articles with CANTICN identifiers', 'Articles with DTBIO identifiers', 'Articles with FAST identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with MusicBrainz identifiers', 'Articles with NDL identifiers', 'Articles with NGV identifiers', 'Articles with NKC identifiers', 'Articles with NTA identifiers', 'Articles with PLWABN identifiers', 'Articles with RKDartists identifiers', 'Articles with SELIBR identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with VcBA identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'British Jews', 'British contemporary artists', 'British humanists', 'British installation artists', 'British male sculptors', 'British people of Indian-Jewish descent', 'CS1 Italian-language sources (it)', 'CS1 maint: bot: original URL status unknown', 'Commanders of the Order of the British Empire', 'Commons category link from Wikidata', 'Indian Jews', 'Indian contemporary artists', 'Indian contemporary sculptors', 'Indian emigrants to England', 'Indian male sculptors', 'Indian people of Iraqi-Jewish descent', 'Jewish artists', 'Jewish sculptors', 'Knights Bachelor', 'Living people', 'Naturalised citizens of the United Kingdom', 'Pages using Template:Post-nominals with customized linking', 'Pages using infobox person with multiple spouses', 'Punjabi artists', 'Recipients of the Padma Bhushan in arts', 'Royal Academicians', 'Short description is different from Wikidata', 'The Doon School alumni', 'Turner Prize winners', 'Use British English from September 2012', 'Use dmy dates from September 2020', 'Webarchive template wayback links']
# category:  ['1688 births', '1763 deaths', 'Articles with FAST identifiers', 'Articles with LCCN identifiers', 'Articles with SELIBR identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'British textile designers', 'Commons category link is on Wikidata', 'English designers', 'EngvarB from September 2014', 'People from the Borough of Melton', 'Short description matches Wikidata', 'Use dmy dates from September 2014', 'Webarchive template wayback links']
# category:  ['1997 sculptures', 'All articles with unsourced statements', 'Articles with short description', 'Articles with unsourced statements from May 2007', 'Articles with unsourced statements from September 2022', 'Cast-iron sculptures', 'Commons category link is on Wikidata', 'Coordinates on Wikidata', 'Iron sculptures in the United Kingdom', 'Metropolitan Borough of Sefton', 'Outdoor sculptures in England', 'Sculptures by Antony Gormley', 'Short description is different from Wikidata', 'Tourist attractions in Merseyside', 'Use British English from December 2012', 'Use dmy dates from July 2020', 'Wikipedia articles needing clarification from October 2018']
# category:  ['1599 births', '1641 deaths', '17th-century English painters', 'ACArt with 16 suppressed elements', 'Articles incorporating Cite DNB template', 'Articles incorporating a citation from the 1913 Catholic Encyclopedia with Wikisource reference', 'Articles with AAG identifiers', 'Articles with BNF identifiers', 'Articles with BPN identifiers', 'Articles with DTBIO identifiers', 'Articles with Dutch-language sources (nl)', 'Articles with GND identifiers', 'Articles with KULTURNAV identifiers', 'Articles with LCCN identifiers', 'Articles with NGV identifiers', 'Articles with NLA identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with TePapa identifiers', 'Articles with Trove identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with multiple identifiers', 'Articles with short description', 'Articles with suppressed authority control identifiers', 'Artists from Antwerp', 'Baroque printmakers', 'Belgian Roman Catholics', 'Belgian expatriates in England', "Burials at St Paul's Cathedral", 'CS1 Polish-language sources (pl)', 'CS1 Spanish-language sources (es)', 'Commons link from Wikidata', 'English portrait painters', 'Flemish Baroque painters', 'Flemish etchers', 'Flemish history painters', 'Flemish portrait painters', 'Knights Bachelor', 'Pages using cite ODNB with id parameter', 'Painters from Antwerp', 'Principal Painters in Ordinary', 'Pupils of Peter Paul Rubens', 'Short description is different from Wikidata', 'Stepney family', 'Use dmy dates from January 2021', 'Webarchive template wayback links', 'Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference', 'Wikipedia articles incorporating a citation from the ODNB']
#  ==> Adding Anthony van Dyck to the list of entries
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# category:  ['1636 births', '1707 deaths', '17th-century English painters', '17th-century Italian painters', '18th-century English painters', '18th-century Italian painters', 'Articles with BNF identifiers', 'Articles with DTBIO identifiers', 'Articles with GND identifiers', 'Articles with ISNI identifiers', 'Articles with LCCN identifiers', 'Articles with RKDartists identifiers', 'Articles with SNAC-ID identifiers', 'Articles with SUDOC identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with hCards', 'Articles with short description', 'Commons category link is on Wikidata', 'English male painters', 'English people of Italian descent', 'Italian Baroque painters', 'Italian emigrants to the Kingdom of England', 'Italian male painters', 'Short description is different from Wikidata', 'Use British English from May 2015', 'Use dmy dates from March 2020']
# category:  ['1874 paintings', 'Paintings in the collection of Royal Holloway, University of London', 'Realist paintings', 'Use dmy dates from April 2022']
# category:  ['Art museums and galleries in London', 'Arthur Wellesley, 1st Duke of Wellington', 'Articles with GND identifiers', 'Articles with J9U identifiers', 'Articles with LCCN identifiers', 'Articles with ULAN identifiers', 'Articles with VIAF identifiers', 'Articles with WORLDCATID identifiers', 'Articles with short description', 'Bathurst family', 'Biographical museums in London', 'Commons category link is on Wikidata', 'Coordinates on Wikidata', 'English Heritage sites in London', 'EngvarB from April 2015', 'Georgian architecture in London', 'Grade I listed buildings in the City of Westminster', 'Grade I listed houses in London', 'Grade I listed museum buildings', 'Greek Revival houses in the United Kingdom', 'Historic house museums in London', 'Houses in the City of Westminster', 'Museums in the City of Westminster', 'Neoclassical architecture in London', 'Official website different in Wikidata and Wikipedia', 'Prime ministerial homes in the United Kingdom', 'Robert Adam buildings', 'Short description is different from Wikidata', 'Use dmy dates from April 2015', 'Webarchive template wayback links']

# %%
## The goal: generate a lorebook dict from a list of text entries.
# list of text entries
entries = [
    'Testing 1',
    'Testing 2',
    'Testing 3'
]
entry_names = [
    'Test 1',
    'Test 2',
    'Test 3'
]

context_config = {
        "prefix": "",
        "suffix": "\n",
        "tokenBudget": 2048,
        "reservedTokens": 0,
        "budgetPriority": 400,
        "trimDirection": "trimBottom",
        "insertionType": "newline",
        "maximumTrimType": "sentence",
        "insertionPosition": -1
      },

# lore_dict > entries > text
lore_dict['entries']['text'] = str(entries[i])
# lore_dict > entries > contextConfig
lore_dict['entries']['contextConfig'] = context_config
# lore_dict > entries > lastUpdatedAt
lore_dict['entries']['lastUpdatedAt'] = '1666044123984'
# lore_dict > entries > displayName
lore_dict['entries']['displayName'] = str(entry_names[i])
# lore_dict > entries > id
lore_dict['entries']['id'] = str(ids[i])
# lore_dict > entries > keys
lore_dict['entries']['keys'] = str(set(keys[i])) # remove duplicates

# %%
# import nltk
# nltk.download('punkt')
import nltk
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

stop_words = set(stopwords.words('english'))

# import the json file lorebook_example.lorebook
with open('Ripple (Mon Oct 17 2022).lorebook') as f:
    lore_dict = json.load(f)


def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# add the entries to the lorebook dictionary. All we have to change is the text, display name, create a random id, and add the keys (which are the words in the text). All other fields can be copied from the first entry.

# create a list of the keys for each entry (all proper nouns, places and dates) 
keys = []
for entry in entries:
    entry_keys = []
    for word, tag in preprocess(entry):
        if tag == 'NNP' or tag == 'NNPS' or tag == 'CD':
            entry_keys.append(word)
    keys.append(entry_keys)

# keys update 2
# add any words in the entry that are unique to that entry compared to all other entries in the lorebook
for i in range(len(entries)):
    for j in range(len(entries)):
        if i != j:
            for word in entries[i].split():
                if word not in entries[j].split() and word not in keys[i]:
                    keys[i].append(word)

# add the entries to the lorebook dictionary
for i in range(len(entries)):
    lore_dict['entries'].append({
        "text": entries[i],
        "contextConfig": {
          "prefix": "",
          "suffix": "\n",
          "tokenBudget": 2048,
          "reservedTokens": 0,
          "budgetPriority": 400,
          "trimDirection": "trimBottom",
          "insertionType": "newline",
          "maximumTrimType": "sentence",
          "insertionPosition": -1
        },
        "lastUpdatedAt": 1666044123984,
        "displayName": entry_names[i],
        "id": ids[i],
        "keys": keys[i],
        "searchRange": 1000,
        "enabled": True,
        "forceActivation": False,
        "keyRelative": False,
        "nonStoryActivatable": False,
        "category": "",
        "loreBiasGroups": [
          {
            "phrases": [],
            "ensureSequenceFinish": False,
            "generateOnce": True,
            "bias": 0,
            "enabled": True,
            "whenInactive": False
          }
        ]
      })
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1129)>

# %%
# save the new lorebook dictionary as a json file called lorebook_generated.lorebook
with open('lorebook_generated.lorebook', 'w') as f:
    json.dump(lore_dict, f, indent=2)

# %%
# preview the new lorebook dictionary

with open('lorebook_generated.lorebook') as f:
    lore_dict = json.load(f)
# Out:
# dict

# %%
import pandas as pd

# %%
keys_dict = '../data/keys_dict.csv'
keys_dict = pd.read_csv(keys_dict).drop(columns=['Unnamed: 0'])
keys_dict.head()
# now each row is an entry with its keys and there is no index column
keys_dict_transposed = keys_dict.transpose()
keys_dict_transposed.head(100)
allkeys = [] # list of all keys
# now each column is an entry with its keys and there is no index column
for col in keys_dict_transposed:
    allkeys.extend(keys_dict_transposed[col].dropna().tolist())
# Out:
# ['Antonio', 'Narciso', 'Luna', 'Pedro', 'Novicio', 'Ancheta', 'Filipino', 'American', 'Artemio', 'Ricarte', 'Commanding', 'General', 'Army', 'Sharpshooters', 'Black', 'Guard', 'Senyor', 'Michael', 'Joaquin', 'three', 'Defense', 'Line', 'Manila', 'Cordillera.Despite', 'Republic', 'Aguinaldo', 'Cabinet', 'Nevertheless', 'Philippine', 'Medal', 'Malolos', 'Congress', 'Family', 'October', 'Calle', 'Urbiztondo', 'Binondo', 'seven', 'Joaqu', 'Posadas', 'Badoc', 'Laureana', 'Namacpacan', 'Union', 'Juan', 'Madrid', 'Escuela', 'Bellas']
# ['British', 'Asia', 'Holy', 'Roman', 'Empire', 'Africa', 'Angola', 'Kasanje', 'Kingdom', 'Kambolo', 'Ngonga', 'King', 'Kamweje', 'Kalunga', 'Mbumba', 'Kinguri', 'Malenge', 'Kitumba', 'Kwango', 'Kalanyi', 'Kiluanje', 'Kongo', 'Henrique', 'XIII', 'Peter', 'Portugal', 'Portuguese', 'Colony', 'Southwest', 'EuropeCameroon', 'Fondom', 'Bafut', 'Achirimbi', 'Abumbi', 'Bamum', 'Ngouhouo', 'Mfon', 'Ngoungoure', 'Nsangou', 'Duala', 'Priso', 'Chief', 'Mbape', 'Bele', 'Kamerun', 'German', 'African']
# ['November', 'Alemanni', 'Rhine', 'Gaul', 'Emperor', 'Paris', 'Gallic', 'Otto', 'Gottschalk', 'Bishop', 'Freising', 'Ostarr', 'Berber', 'Sulayman', 'Hakam', 'Umayyad', 'Muhammad', 'Alcolea', 'Empress', 'Matilda', 'English', 'Stephen', 'Blois', 'England', 'Philip', 'France', 'Sinope', 'Seljuq', 'Turks', 'Union', 'Valencia', 'Jews', 'Murviedro', 'King', 'Pope', 'Julius', 'Sistine', 'Chapel', 'Michelangelo', 'Strait', 'Magellan', 'South', 'America', 'Pacific', 'Atlantic', 'Oceans', 'Ferdinand', 'Huguenots', 'Antarctique']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ['Cholera', 'Vibrio', 'Diarrhea', 'five', 'Food', 'Drug', 'Administration', 'Vaxchora', 'Rice', 'Zinc', 'Ringer', 'million', '28,800', '130,000', 'seven', 'Areas', 'Africa', 'Southeast', 'Asia', 'Sanskrit', 'Europe', 'England', 'John', 'Snow', 'Signs', 'Severe', 'Kussmaul', 'Blood', 'Muscle', 'Cause', 'Transmission', 'Children', 'four', 'AIDS', 'F508', 'Binding', 'Virulent', 'TcpP', 'TcpH', 'ToxR', 'ToxS', 'ToxT']
# ['April', 'Battle', 'Megido', 'Vitellius', 'Bedriacum', 'Otho', 'Masada', 'Romans', 'First', 'Jewish', 'Roman', 'Stefan', 'Mighty', 'Emperor', 'Serbs', 'Skopje', 'Balkans', 'Revolt', 'Comuneros', 'Spain', 'Charles', 'Spanish', 'Hernando', 'Lerma', 'Salta', 'Argentina', 'Culloden', 'William', 'Augustus', 'Duke', 'Cumberland', 'Scotland', 'Highlands', 'Franz', 'Friedrich', 'Wilhelm', 'University', 'Revolutionary', 'Mount', 'Tabor', 'Napoleon', 'Ottoman', 'Turks', 'River', 'Jordan', 'Acre', 'United', 'States', 'Senate']
# ['Giovanni', 'Segantini', 'Alps', 'Europe', 'Symbolist', 'Switzerland', 'Biography', 'Battista', 'Emanuele', 'Maria', 'Segatini', 'Arco', 'Trentino', 'County', 'Tyrol', 'Austro', 'Hungarian', 'Empire', 'Agostino', 'Margarita', 'Girardi', 'Lodovico', 'seven', 'Irene', 'Milan', 'Italy', 'Marchiondi', 'Reformatory', 'Napoleon', 'Brera', 'Academy', 'Scapigliatura', 'Carlo', 'Bugatti', 'Emilio', 'Longoni', 'Chancel', 'Sant', 'Antonio', 'Societ', 'Belle', 'Arti', 'Vittore', 'Grubicy', 'Dragon', 'Alberto', 'Anton', 'Mauve']
# ['Henry', 'Ware', 'Lawton', 'U.S.', 'Army', 'Civil', 'Apache', 'Wars', 'American', 'United', 'States', 'Oklahoma', 'General', 'Havana', 'Cuba', 'Liwasang', 'Bonifacio', 'Manila', 'Plaza', 'March', 'Maumee', 'Ohio', 'George', 'Catherine', 'December', 'Manley', 'Chapin', 'Fort', 'Wayne', 'Indiana', 'California', 'January', 'Birmingham', 'Sandusky', 'Andrew', 'Barney', 'Florence', 'Township', 'Marie', 'Iowa', 'Missouri', 'Methodist', 'Episcopal', 'College', 'President', 'Abraham', 'Lincoln', 'three']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ['Empire', 'Imperial', 'Germany', 'Kaiserreich', 'Second', 'Reich', 'November', 'Revolution', 'January', 'Austria', 'April', 'Emperor', 'Wilhelm', 'King', 'Prussia', 'House', 'Hohenzollern', 'Berlin', 'Otto', 'Bismarck', 'Minister', 'President', 'Chancellor', 'Prussian', 'Confederation', 'Baden', 'Bavaria', 'Hesse', 'Franco', 'four', 'five', 'seven', 'three', 'Hanseatic', 'million', 'Nobel', 'Prizes', 'Europe', 'Continental', 'Britain', 'Royal', 'Navy', 'Weltpolitik', 'World', 'Kulturkampf', 'Scramble']
# ['Nokia', 'Bell', 'Labs', 'Telephone', 'Laboratories', 'Innovations', 'Murray', 'Hill', 'Jersey', 'United', 'States', 'Unix', 'SNOBOL', 'AMPL', 'Nine', 'Nobel', 'Prizes', 'Laboratories.Bell', 'System', 'Electric', 'Engineering', 'Department', 'West', 'Street', 'York', 'City', 'American', 'Telegraph', 'Company', 'Western', '1960s', 'Alexander', 'Graham', 'Volta', 'Prize', '50,000', 'Laboratory', 'Washington', 'D.C.', 'Sumner', 'Tainter', 'Chichester', 'Bureau', 'Carriage', 'House', '1889.In', 'N.W.', 'National']
# ['January', 'Battle', 'Bakhamra', 'Alids', 'Abbasids', 'Kufa', 'Alid', 'Ibrahim', 'Musa', 'Anabaptist', 'Movement', 'Conrad', 'Grebel', 'Felix', 'Manz', 'George', 'Blaurock', 'thousand', 'Affair', 'Placards', 'Protestant', 'Paris', 'Sweden', 'Prussia', 'Treaty', 'Stockholm', 'Teatro', 'Filarmonico', 'Verona', 'Abdul', 'Hamid', 'Sultan', 'Ottoman', 'Empire', 'Caliph', 'Islam', 'American', 'Power', 'Sympathy', 'Triumph', 'Nature', 'Founded', 'Truth', 'William', 'Hill', 'Brown', 'Boston', 'National', 'Convention', 'Louis']
# ['Arthur', 'Ignatius', 'Conan', 'Doyle', 'Sherlock', 'Holmes', 'Study', 'Scarlet', 'four', 'Watson', 'Professor', 'Challenger', 'Napoleonic', 'Brigadier', 'Gerard', 'Habakuk', 'Jephson', 'Statement', 'Mary', 'Celeste', 'Cathedral', 'Edinburgh', 'Michael', 'Library', 'Congress', 'Baker', 'Street', 'Journal', 'Picardy', 'Place', 'Scotland', 'Charles', 'Altamont', 'England', 'Irish', 'Catholic', 'Burton', 'Liberton', 'Bank', 'House', 'Gilmerton', 'Road', 'Newington', 'Academy.In', 'Crichton', 'Royal']
# ['British', 'Asia', 'Holy', 'Roman', 'Empire', 'Africa', 'Angola', 'Kasanje', 'Kingdom', 'Kambolo', 'Ngonga', 'King', 'Kamweje', 'Kalunga', 'Mbumba', 'Kinguri', 'Malenge', 'Kitumba', 'Kwango', 'Kalanyi', 'Kiluanje', 'Kongo', 'Henrique', 'XIII', 'Peter', 'Portugal', 'Portuguese', 'Colony', 'Southwest', 'EuropeCameroon', 'Fondom', 'Bafut', 'Achirimbi', 'Abumbi', 'Bamum', 'Ngouhouo', 'Mfon', 'Ngoungoure', 'Nsangou', 'Duala', 'Priso', 'Chief', 'Mbape', 'Bele', 'Kamerun', 'German', 'African']
# ['August', 'Goguryeo', 'Liaoxi', 'Emperor', 'Yang', 'Liang', 'Manchurian', 'Barons', 'Battle', 'Evesham', 'Prince', 'Edward', 'Simon', 'Montfort', 'Earl', 'Leicester', 'First', 'James', 'Douglas', 'Weardale', 'England', 'Kasr', 'Kebir', 'Moroccans', 'Portuguese', 'King', 'Sebastian', 'Portugal', 'Cardinal', 'Henry', 'Date', 'Perignon', 'Great', 'Peace', 'Montreal', 'France', 'Nations', 'Gibraltar', 'Dutch', 'Admiral', 'George', 'Rooke', 'Archduke', 'Charles']
# ['Robert', 'LeRoy', 'Parker', 'Butch', 'Cassidy', 'Wild', 'Bunch', 'West', 'Pinkerton', 'Harry', 'Longabaugh', 'Sundance', 'Etta', 'Place', 'Argentina', 'Bolivia', 'Army', 'November', 'April', 'Beaver', 'Utah', 'Territory', 'Campbell', 'Gillies', 'Mormon', 'United', 'Kingdom', 'Salt', 'Lake', 'City', 'Tyneside', 'England', 'U.S.', 'July', 'Circleville', 'Mike', 'Rock', 'Springs', 'Wyoming', 'Criminal', 'Telluride', 'Colorado', 'Montana', 'Matt', 'Warner', 'June']
# ['Line', 'Philadelphia', 'Pennsylvania', 'Railroad', 'International', 'Navigation', 'United', 'States', 'York', 'City', 'Liverpool', 'Southampton', 'Sister', 'Star', 'America', 'Antwerp', 'Belgium', 'Clement', 'Griscom', 'Baltimore', 'Atlantic', 'Transport', 'Lines', 'American', 'White', 'Cunard', 'HAPAG', 'Inman', 'Mercantile', 'Marine', 'Company', 'Ships', 'Berlin', 'seven', 'Paris', 'Haverford', 'four', 'Merion', 'Illinois', 'Indiana', 'Kensington', 'Kroonland', 'Panama', 'Pacific', 'Pittsburgh', 'Pennland']
# ['April', 'Thutmose', 'Egypt', 'Hatshepsut', 'Traditional', 'Fall', 'Troy', 'Trojan', 'Library', 'Alexandria', 'Eratosthenes', 'Battle', 'Duke', 'Alba', 'Imperial', 'Charles', 'Spain', 'Schmalkaldic', 'League', 'Mary', 'Queen', 'Scots', 'Dauphin', 'France', 'Fran', 'Notre', 'Dame', 'Paris', 'British', 'Colonial', 'America', 'Boston', 'News', 'Letter', 'Jean', 'Paul', 'Marat', 'Revolutionary', 'Tribunal', 'Girondin', 'United', 'States', 'Congress', 'President', 'John', 'Adams', '5,000', 'Surat', 'India']
# ['April', 'Lothair', 'King', 'Italy', 'Pope', 'Paschal', 'Fatimid', 'Egypt', "Qa'im", 'Allah', 'Raqqada', 'Battle', 'Lake', 'Peipus', 'Alexander', 'Nevsky', 'Teutonic', 'Knights', 'Charles', 'Entry', 'Rome', 'Roman', 'Dutch', 'Hendrick', 'Brederode', 'Margaret', 'Parma', 'Petition', 'Compromise', 'Inquisition', 'Seventeen', 'Provinces', 'Virginia', 'Pocahontas', 'English', 'John', 'Rolfe', 'Mayflower', 'Plymouth', 'Massachusetts', 'England', 'United', 'States', 'President', 'George', 'Washington', 'Basel', 'France']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ['Association', 'million', 'Laws', 'Game', 'International', 'Football', 'Board', 'FIFA', 'World', 'Women', 'Olympic', 'Games', 'Final', 'four', 'Uruguay', '1980s', 'China', 'France', '1.12', 'billion', 'UEFA', 'Champions', 'League', 'five', 'Premier', 'Liga', 'Bundesliga', 'Serie', 'Ligue', '1.185', 'Oxford', 'University', 'England', 'Rugby', 'School', 'English', 'Great', 'Britain', 'Ulster', 'Ireland', 'Australia', 'Canada', 'South', 'Africa', 'United', 'States']
# ['November', 'Lothair', 'Abbey', 'Saint', 'Remi', 'West', 'Kingdom', 'Future', 'Byzantine', 'Romanos', 'Argyros', 'Battle', 'Posada', 'Voievode', 'Basarab', 'Plymouth', 'English', 'Parliament', 'Wilberforce', 'Monument', 'Kingston', 'Upon', 'Hull', 'Pudge', 'Heffelfinger', 'American', 'Allegheny', 'Athletic', 'Association', 'Abdur', 'Rahman', 'Khan', 'Durand', 'Line', 'Emirate', 'Afghanistan', 'Norway', 'Storting', 'First', 'Balkan', 'King', 'George', 'Greece', 'Thessaloniki', 'Ottoman', 'Robert', 'Scott']
# ['John', 'Pierpont', 'Morgan', 'Wall', 'Street', 'Gilded', 'J.P.', 'United', 'States', '19th', 'U.S.', 'Steel', 'International', 'Harvester', 'General', 'Electric', 'Aetna', 'Western', 'Union', 'Pullman', 'Company', 'Panic', 'American', 'Progressive', 'Wooldridge', 'America', 'Rome', 'Italy', 'Biographer', 'Chernow', 'million', 'Childhood', 'Hartford', 'Connecticut', 'Junius', 'Spencer', 'Juliet', 'Public', 'School', 'Episcopal', 'Academy', 'Cheshire', 'September']
# ['August', 'Goguryeo', 'Liaoxi', 'Emperor', 'Yang', 'Liang', 'Manchurian', 'Barons', 'Battle', 'Evesham', 'Prince', 'Edward', 'Simon', 'Montfort', 'Earl', 'Leicester', 'First', 'James', 'Douglas', 'Weardale', 'England', 'Kasr', 'Kebir', 'Moroccans', 'Portuguese', 'King', 'Sebastian', 'Portugal', 'Cardinal', 'Henry', 'Date', 'Perignon', 'Great', 'Peace', 'Montreal', 'France', 'Nations', 'Gibraltar', 'Dutch', 'Admiral', 'George', 'Rooke', 'Archduke', 'Charles']
# ['British', 'Asia', 'Holy', 'Roman', 'Empire', 'Africa', 'Angola', 'Kasanje', 'Kingdom', 'Kambolo', 'Ngonga', 'King', 'Kamweje', 'Kalunga', 'Mbumba', 'Kinguri', 'Malenge', 'Kitumba', 'Kwango', 'Kalanyi', 'Kiluanje', 'Kongo', 'Henrique', 'XIII', 'Peter', 'Portugal', 'Portuguese', 'Colony', 'Southwest', 'EuropeCameroon', 'Fondom', 'Bafut', 'Achirimbi', 'Abumbi', 'Bamum', 'Ngouhouo', 'Mfon', 'Ngoungoure', 'Nsangou', 'Duala', 'Priso', 'Chief', 'Mbape', 'Bele', 'Kamerun', 'German', 'African']
# ['February', 'Alaric', 'Visigoths', 'Breviary', 'Roman', 'Battle', 'Heath', 'King', 'Louis', 'France', 'Norse', 'Great', 'Heathen', 'Army', 'Saxony', 'Translatio', 'Pope', 'John', 'Otto', 'Holy', 'Emperor', 'Conrad', 'Burgundy', 'Lincoln', 'Stephen', 'England', 'Empress', 'Matilda', 'Terra', 'Mariana', 'Latvia', 'Estonia', 'Nine', 'Torda', 'Wars', 'Mortimer', 'Cross', 'Owen', 'Tudor', 'Spaniard', 'Pedro', 'Mendoza', 'Buenos', 'Aires', 'Argentina', 'Scotland', 'Three', 'Kingdoms', 'Inverlochy']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ['January', 'Emperor', 'Gratian', 'Flavius', 'Theodosius', 'Sirmium', 'Augustus', 'Roman', 'Empire', 'Conquest', 'Kucha', 'Tang', 'Ashina', "She'er", 'Tarim', 'Basin', 'Xinjiang', 'Hundred', 'Years', 'Henry', 'England', 'Normandy', 'Duchy', 'Mirandola', 'Pope', 'Sten', 'Sture', 'Younger', 'Regent', 'Sweden', 'Battle', 'Bogesund', 'February', 'Agustin', 'Church', 'Manila', 'Philippines', 'Vanaja', 'Tavastia', 'John', 'Wilkes', 'House', 'Commons', 'Bolle', 'Willum', 'Luxdorph', 'Danish', 'Colonel', 'Poulsen']
# ['Sibelius', 'Johan', 'Julius', 'Christian', 'December', 'September', 'Romantic', 'Finland', 'Russia', 'seven', 'Finlandia', 'Karelia', 'Suite', 'Valse', 'Violin', 'Concerto', 'Kullervo', 'Swan', 'Tuonela', 'Nordic', 'Kalevala', 'Jungfrun', 'Masonic', '1920s', 'Symphony', 'Tempest', 'Tapiola', 'Finnish', 'Music', 'Helsinki', 'Life', 'Grand', 'Duchy', 'Russian', 'Empire', 'Gustaf', 'Maria', 'Charlotta', 'Sibbe', 'Eastern', 'Uusimaa', 'July', 'Katarina', 'Borg', 'Pehr', 'Ferdinand', 'Uncle', 'Loviisa', 'Julia', 'Linda']
# ['November', 'Alemanni', 'Rhine', 'Gaul', 'Emperor', 'Paris', 'Gallic', 'Otto', 'Gottschalk', 'Bishop', 'Freising', 'Ostarr', 'Berber', 'Sulayman', 'Hakam', 'Umayyad', 'Muhammad', 'Alcolea', 'Empress', 'Matilda', 'English', 'Stephen', 'Blois', 'England', 'Philip', 'France', 'Sinope', 'Seljuq', 'Turks', 'Union', 'Valencia', 'Jews', 'Murviedro', 'King', 'Pope', 'Julius', 'Sistine', 'Chapel', 'Michelangelo', 'Strait', 'Magellan', 'South', 'America', 'Pacific', 'Atlantic', 'Oceans', 'Ferdinand', 'Huguenots', 'Antarctique']
# ['Westinghouse', 'Electric', 'Corporation', 'George', 'Manufacturing', 'Company', 'Viacom', 'April', 'Licensing', 'History', 'Pittsburgh', 'Pennsylvania', 'January', 'United', 'States', 'East', 'Lester', 'Hamilton', 'Ontario', 'Frank', 'Conrad', 'Benjamin', 'Garver', 'Lamme', 'Bertha', 'Oliver', 'Shallenberger', 'William', 'Stanley', 'Nikola', 'Tesla', 'Stephen', 'Timoshenko', 'Vladimir', 'Zworykin', 'Early', 'Thomas', 'Edison', 'Thomson', 'Houston', 'General', 'Financial', 'billion', 'Credit', 'Inc.', 'Power', 'Generation']
# ['Otto', 'Prince', 'Bismarck', 'Count', 'Duke', 'Lauenburg', 'April', 'July', 'Eduard', 'Leopold', 'Junker', 'Prussia', 'Russia', 'France', 'Parliament', 'Germany', 'Chancellor', 'Empire', 'Kingdom', 'King', 'Wilhelm', 'three', 'Denmark', 'Austria', 'Confederation', 'German', 'Europe', 'Eric', 'Hobsbawm', 'twenty', 'Alsace', 'Lorraine', 'Germanophobia', 'Realpolitik', 'Iron', '1870s', 'Catholic', 'Liberals', 'Church', 'Kulturkampf', 'Catholics', 'Centre', 'Party', 'Socialists', 'Lutheran', 'Emperor', 'Empress', 'Crown', 'Imperial']
# ['Different', 'Anarchism', 'Social', 'Economic', 'Karl', 'Marx', 'Friedrich', 'Engels', '1920s', 'Soviet', 'Union', 'Bloc', 'Britain', 'France', 'Sweden', 'Cold', 'Andrew', 'Vincent', 'Latin', 'Roman', 'Pierre', 'Leroux', 'Globe', 'Henri', 'Saint', 'Simon', 'Industrial', 'Revolution', 'Robert', 'Owen', 'Marie', 'Roch', 'Louis', 'Reybaud', 'Bolshevik', 'Vladimir', 'Lenin', 'Russia', 'Democratic', 'Labour', 'Party', 'Russian', 'Communist', 'Bolshevism', 'Leninism', 'Marxism']
# ['Orange', 'Free', 'State', 'Boer', 'Southern', 'Africa', 'Second', 'three', 'Vaal', 'United', 'Kingdom', 'Great', 'Britain', 'Ireland', 'River', 'Sovereignty', 'Resident', 'Bloemfontein', 'Griqua', 'Trekboere', 'Cape', 'Colony', 'Voortrekker', 'Republic', 'Natalia', 'Winburg', 'Potchefstroom', 'South', 'African', 'Transvaal', 'February', 'Convention', 'Republic.The', 'Treaty', 'Vereeniging', 'Union', 'Province', 'Natal', 'Africa.The', 'Dutch', 'House', 'Robert', 'Jacob', 'Gordon', 'History', 'First', 'Europeans']
# ['Polyphase', 'Systems', 'Number', 'four', 'Scott', 'Motors', 'Induction', 'Galileo', 'Ferraris', 'Nikola', 'Tesla', 'Mikhail', 'Dolivo', 'Dobrovolsky', 'Once', 'York', 'State', 'Electric', '115KV', '93KV', '1.732', 'Single', 'Delta', 'Phase', 'References', 'Further', 'Thompson', 'Chamberlain']
# ['July', 'Constantine', 'Bridge', 'Danube', 'Sucidava', 'Oescus', 'Roman', 'Theophilus', 'Patricius', 'Burgundian', 'Majorcan', 'Principality', 'Achaea', 'Battle', 'Manolada', 'Pedro', 'Lopes', 'Sousa', 'Kingdom', 'Kandy', 'Campaign', 'Danture', 'Lanka', 'John', 'Bristol', 'Newfoundland', 'Isaac', 'Newton', 'Philosophi', 'Naturalis', 'Principia', 'Mathematica', 'Chesma', 'Russian', 'Empire', 'Ottoman', 'Second', 'Continental', 'Congress', 'Olive', 'Branch', 'Petition', 'Convention', 'Artlenburg', 'Electorate', 'Hanover', 'Buenos', 'Aires', 'English']
# ['League', 'Nations', 'January', 'Paris', 'Peace', 'Conference', 'World', 'April', 'United', 'Covenant', 'Europe', 'June', 'Part', 'Treaty', 'Versailles', 'Council', 'Assembly', 'November', 'U.S.', 'Woodrow', 'Wilson', 'Nobel', 'Prize', 'hundred', 'First', 'Allies', 'Powers', 'Second', 'Italo', 'Ethiopian', 'International', 'Cross', 'Crescent', 'Movement', 'Benito', 'Mussolini', 'September', 'February', '1920s', 'Axis', '1930s', 'States', 'Japan', 'Italy', 'Germany', 'Spain', 'Soviet', 'Union', 'Finland']
# ['American', 'West', 'mainland', 'North', 'America', 'President', 'Thomas', 'Jefferson', 'Louisiana', 'Purchase', 'Manifest', 'Destiny', 'Frontier', 'Thesis', 'United', 'States', 'Civil', 'Census', 'Bureau', '1890.By', 'Frederick', 'Jackson', 'Turner', 'Mississippi', 'River', 'Midwest', 'Texas', 'Great', 'Plains', 'Rocky', 'Mountains', 'Southwest', 'Coast', 'Enormous', 'Western', '1850s', '1910s', 'Hine', 'Faragher', 'Americans', 'Europeans', 'David', 'Murdoch', 'U.S.', 'East', '1600s', 'Maine', 'Vermont']
# ['1880s', 'American', 'George', 'Eastman', 'Eadweard', 'Muybridge', 'Zoopraxiscope', 'January', 'Plate', 'Company', 'William', 'Walker', 'Jules', 'Marey', 'Hannibal', 'Goodwin', 'Louis', 'Prince', 'Roundhay', 'Garden', 'Scene', 'Leeds', 'Yorkshire', 'England', '2.11', 'Thomas', 'Edison', 'Births', 'Film', 'History']
# ['Charles', 'Sumner', 'Tainter', 'Alexander', 'Graham', 'Bell', 'Chichester', 'Gardiner', 'Hubbard', 'Thomas', 'Edison', 'Graphophone', 'Dictaphone.Later', 'International', 'Graphopone', 'Company', 'West', 'Virginia', "'Father", 'Talking', 'Machine', 'Biography', 'Watertown', 'Massachusetts', 'Alvan', 'Clark', 'Sons', 'Cambridge', 'U.S.', 'Navy', 'Venus', 'December', 'Zealand', 'Cambridgeport', 'Volta', 'Laboratory', 'Washington', 'D.C.', 'Bells', 'Lila', 'Munro', 'Dictaphone', 'Diego', 'California', 'Laura', 'Onderdonk', 'Fontaine']
# ['October', 'Roman', 'Nerva', 'Guard', 'Marcus', 'Ulpius', 'Trajanus', 'Maxentius', 'Constantine', 'West', 'Byzantine', 'Empire', 'Arab', 'Smyrna', 'Beijing', 'Ming', 'Forbidden', 'City', 'Denmark', 'Ladislaus', 'Posthumous', 'Bohemia', 'Prague', 'Christopher', 'Columbus', 'Cuba', 'World', 'Japan', 'Ottoman', 'Mamluk', 'Mamluks', 'Egypt', 'Battle', 'Yaunis', 'Khan', 'Ferdinand', 'Magellan', 'Pacific', 'Ocean', 'Adal', 'Sultanate', 'Ethiopia', 'Universidad', 'Santo', 'Aquino', 'Dominican', 'Republic']
# ['Sunday', 'Friday', 'Julian', '1899th', 'Common', 'Anno', 'Domini', '899th', '99th', '10th', '1890s', 'January', 'Cuba', 'Americas', 'Staten', 'Island', 'York', 'City', 'Bolivia', 'Puerto', 'Alonso', 'Republic', 'Acre', 'Jakarta', 'Kota', 'Anyer', 'Kidul', 'Java', 'Batavia', 'Zuid', 'Tangerang', 'Hungarian', 'Prime', 'Minister', 'Dezs', 'U.S.', 'President', 'William', 'McKinley', 'December', 'Philippines', 'United', 'States', 'Manila', 'General', 'Elwell', 'Otis']
# ['Marxism', 'Humans', 'Enlightenment', '19th', 'Paris', 'Commune', 'Russian', 'Civil', 'Anarchism', 'Anarchist', 'Etymology', 'Ancient', 'Greek', 'English', 'Revolution', 'William', 'Godwin', 'Wilhelm', 'Weitling', 'Pierre', 'Joseph', 'Proudhon', '1890s', 'France', 'United', 'States', 'Left', 'Additionally', 'History', 'China', 'Greece', 'Taoist', 'Zhuang', 'Zhou', 'Laozi', 'Alongside', 'Stoicism', 'Taoism', 'Aeschylus', 'Sophocles', 'Antigone', 'Europe', 'Muslim', 'Empire', 'Mazdak', 'Emperor', 'Kavad']
# ['United', 'States', '5,280', 'English', '1,760', 'Commonwealth', '1,609.344', 'Roman', 'Romans', '5,000', 'Elizabethan', 'England', 'Empire', 'Geological', 'Survey', '2022', 'International', 'System', 'Units', 'Liberia', 'Kingdom', 'million', 'Middle', 'Germanic', 'Parliament', 'Foreign', 'Antonine', 'Itinerary', 'Abbreviation', 'National', 'Institute', 'Standards', 'Technology', 'Historical', '1,000', 'Well', 'Agrippa', 'Imperial', '1,618', 'Hellenic', 'Byzantine', 'Milion', 'Mese', 'Hagia', 'Sophia', 'Europe', 'Forum']
# ['November', 'Alemanni', 'Rhine', 'Gaul', 'Emperor', 'Paris', 'Gallic', 'Otto', 'Gottschalk', 'Bishop', 'Freising', 'Ostarr', 'Berber', 'Sulayman', 'Hakam', 'Umayyad', 'Muhammad', 'Alcolea', 'Empress', 'Matilda', 'English', 'Stephen', 'Blois', 'England', 'Philip', 'France', 'Sinope', 'Seljuq', 'Turks', 'Union', 'Valencia', 'Jews', 'Murviedro', 'King', 'Pope', 'Julius', 'Sistine', 'Chapel', 'Michelangelo', 'Strait', 'Magellan', 'South', 'America', 'Pacific', 'Atlantic', 'Oceans', 'Ferdinand', 'Huguenots', 'Antarctique']
# ['Nikola', 'Tesla', 'American', 'Empire', '1870s', '1880s', 'Continental', 'Edison', 'United', 'States', 'Machine', 'Works', 'York', 'City', 'Westinghouse', 'Electric', '1890s', 'Colorado', 'Springs', 'Wardenclyffe', 'Tower', '1910s', '1920s', 'January', 'General', 'Conference', 'Weights', 'Measures', '1990s', 'Smiljan', 'Military', 'Frontier', 'July', 'June', 'Milutin', 'Eastern', 'Orthodox', 'Church.Tesla', 'Mandi', 'Church', 'Serbia', 'Montenegro.Tesla', 'five', 'three', 'Milka', 'Angelina', 'Marica', 'Dane']
# ['London', 'England', 'United', 'Kingdom', 'million', 'River', 'Thames', 'North', 'City', 'Romans', 'Londinium', 'Westminster', 'Middlesex', 'Essex', 'Surrey', 'Kent', 'Hertfordshire', 'Greater', 'Authority.As', 'Europe', '2021', 'Imperial', 'College', 'School', 'Economics', 'University', 'Underground', '13.4', 'Built', 'Area', 'four', 'World', 'Heritage', 'Tower', 'Gardens', 'Palace', 'Abbey', 'Margaret', 'Church', 'Greenwich', 'Royal', 'Observatory', 'Mean', 'Time', 'Buckingham']
# ['Charles', 'Proteus', 'Steinmetz', 'Union', 'College', 'United', 'States', 'Forger', 'Thunderbolts', 'Wizard', 'Schenectady', 'IEEE', 'Award', 'Institute', 'Electrical', 'Electronics', 'Engineers', 'Karl', 'August', 'Rudolph', 'April', 'Breslau', 'Province', 'Silesia', 'Prussia', 'Caroline', 'Heinrich', 'Lutheran', 'Evangelical', 'Church', 'four', 'Johannes', 'Gymnasium', 'University', 'Germany', 'Cornell', 'Professor', 'Ronald', 'Kline', 'Socialist', 'Odyssey', 'Americans', 'Technical', 'Alliance', 'Thorstein', 'Veblen', 'Leland', 'Olds', 'three', 'Rudolf']
# ['July', 'Constantine', 'Bridge', 'Danube', 'Sucidava', 'Oescus', 'Roman', 'Theophilus', 'Patricius', 'Burgundian', 'Majorcan', 'Principality', 'Achaea', 'Battle', 'Manolada', 'Pedro', 'Lopes', 'Sousa', 'Kingdom', 'Kandy', 'Campaign', 'Danture', 'Lanka', 'John', 'Bristol', 'Newfoundland', 'Isaac', 'Newton', 'Philosophi', 'Naturalis', 'Principia', 'Mathematica', 'Chesma', 'Russian', 'Empire', 'Ottoman', 'Second', 'Continental', 'Congress', 'Olive', 'Branch', 'Petition', 'Convention', 'Artlenburg', 'Electorate', 'Hanover', 'Buenos', 'Aires', 'English']
# ['Napoleonic', 'Wars', 'Congress', 'Vienna', 'First', 'World', 'Paris', 'Peace', 'Conference', 'Important', 'Great', 'Britain', 'United', 'States', 'France', 'Prussia', 'Germany', 'Italy', 'Japan', 'Scramble', 'Africa', '1880s', '1890s', 'Royal', 'Navy', 'Russia', 'Ottoman', 'Empire', 'Balkan', 'five', 'Austria', 'Powers', 'Romania', 'Bulgaria', 'Serbia', 'Montenegro', 'Europe', 'Triple', 'Entente', 'Alliance', 'Hungary', 'Central', 'Neutrality', 'Belgium', 'Netherlands', 'Luxembourg', 'Denmark', 'Sweden', 'Norway']
# ['Helium', 'United', 'States', 'Semi', 'Count', 'Luftschiffbau', '1940s', 'R101', 'France', 'U.S.', 'Navy', 'Akron', 'Macon', 'Hindenburg', '1960s', 'Terminology', 'Airship', 'Frederick', 'Handley', 'Page', '1930s', 'Aerostat', '3,000', 'Platform', 'Wireless', 'International', 'Corporation', '1,250', 'Brazil', 'European', 'Union', 'ABSOLUTE', 'Henri', 'Giffard', 'September', 'Goodyear', 'Blimp', 'Later', 'Company', 'Luftschiff', 'Hybrid', 'Classification', 'Airships', 'Rigid', 'Construction']
# ['Sunday', 'Friday', 'Julian', '1899th', 'Common', 'Anno', 'Domini', '899th', '99th', '10th', '1890s', 'January', 'Cuba', 'Americas', 'Staten', 'Island', 'York', 'City', 'Bolivia', 'Puerto', 'Alonso', 'Republic', 'Acre', 'Jakarta', 'Kota', 'Anyer', 'Kidul', 'Java', 'Batavia', 'Zuid', 'Tangerang', 'Hungarian', 'Prime', 'Minister', 'Dezs', 'U.S.', 'President', 'William', 'McKinley', 'December', 'Philippines', 'United', 'States', 'Manila', 'General', 'Elwell', 'Otis']
# ['Enclave', 'Vatican', 'City', 'Marino', 'Italy', 'Lesotho', 'South', 'Africa', 'Azerbaijani', 'Nakhchivan', 'Semi', 'Pene', 'Point', 'Roberts', 'Washington', 'Minnesota', 'Northwest', 'Angle', 'Kleinwalsertal', 'Vorarlberg', 'Austria', 'Germany', 'Origin', 'Latin', 'Treaty', 'Madrid', '1526.', 'Later', 'English', 'India', 'Characteristics', 'Europe', 'Holy', 'Roman', 'Empire', 'Prior', 'Prussia', 'August', 'Bangladesh', 'Land', 'Boundary', 'Agreement', 'Indo', 'Dahagram', 'Angarpota', 'Netherlands', 'Belgium', 'Baarle']
# ['Alexander', 'Graham', 'Bell', 'American', 'Telephone', 'Telegraph', 'Company', '1885.Bell', 'U.S.', 'March', 'National', 'Geographic', 'Society', 'January', 'Edinburgh', 'Scotland', 'South', 'Charlotte', 'Street', 'Melville', 'James', 'Edward', 'Charles', 'Eliza', 'Grace', 'Born', '11th', 'Aleck', 'Herdman', 'John', 'London', 'Dublin', 'Standard', 'Elocutionist', 'million', 'United', 'States', 'Speech', 'Latin', 'Scottish', 'Gaelic', 'Sanskrit', 'Royal', 'High', 'School', 'four', 'Harrington', 'Square', 'Weston']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ['November', 'Emperor', 'Zeno', 'Byzantine', 'Empire', 'Bian', 'Yang', 'State', 'Southern', 'Tang', 'Fourth', 'Crusade', 'Pope', 'Innocent', 'Catholic', 'Zara', 'Raden', 'Wijaya', 'Majapahit', 'Java', 'Kertarajasa', 'Jayawardhana', 'Battle', 'Varna', 'King', 'Poland', 'Turks', 'Sultan', 'Murad', 'Bloodbath', 'Duke', 'Charles', 'Great', 'Square', 'Turku', 'Sigismund', 'Cudgel', 'Chattrapati', 'Shivaji', 'Maharaj', 'Maratha', 'Afzal', 'Khan', 'Adilshahi', 'Pratapgarh', 'Third']
# ['History', 'IEEE', 'Milestones', 'Institute', 'Electrical', 'Electronics', 'Engineers', 'Prior', 'Leyden', 'Ewald', 'Georg', 'Kleist', 'Pieter', 'Musschenbroek', 'Book', 'Experiments', 'Observations', 'Electricity', 'Benjamin', 'Franklin', 'London', 'Alessandro', 'Volta', 'Battery', 'Nicholas', 'Callan', 'Science', 'Technology', 'Pavel', 'Schilling', 'Practical', 'Telegraphy', 'Demonstration', 'Electric', 'Fire', 'Alarm', 'System', 'Heinrich', 'Geissler', 'Maxwell', 'Transcontinental', 'Telegraph', 'Landing', 'Transatlantic', 'Cable', 'County', 'Kerry', 'Stations', 'First', 'Voice']
# ['Pierre', 'Marie', 'Ernest', 'Waldeck', 'Rousseau', 'Republican', '29th', 'Prime', 'Minister', 'France', 'Nantes', 'Brittany', 'Constituent', 'Assembly', 'Loire', 'Poitiers', 'Paris', 'January', 'Jules', 'Nazaire', 'September', 'National', 'Defence', 'Third', 'Republic', 'Rennes', 'Chamber', 'Deputies', 'Union', 'Gambetta.The', 'Catholic', 'Ferry', 'Gambetta', 'Capital', 'Martin', 'Feuill', 'Alexandre', 'Lacassagne', 'Gustave', 'Eiffel', 'Panama', 'Faure', 'Henri', 'Brisson', 'Conservatives']
# ['Colorado', 'Springs', 'Paso', 'County', 'United', 'States', '478,961', '2020', 'Census', '15.02', '40th', 'Metropolitan', 'Statistical', 'Area', 'Front', 'Range', 'Urban', 'Corridor', 'Fountain', 'Creek', 'Denver', '6,035', 'Pikes', 'Peak', '14,115', 'Southern', 'Rocky', 'Mountains', 'History', 'Arapaho', 'Cheyenne', 'Louisiana', 'Purchase', 'Kansas', 'Territory', 'Jefferson', 'October', 'November', 'City', 'Camp', 'August', 'Gold', 'Rush', 'Golden', 'England', 'Little', 'London', 'Company', 'Font', 'Colony']
# ['April', 'Lothair', 'King', 'Italy', 'Pope', 'Paschal', 'Fatimid', 'Egypt', "Qa'im", 'Allah', 'Raqqada', 'Battle', 'Lake', 'Peipus', 'Alexander', 'Nevsky', 'Teutonic', 'Knights', 'Charles', 'Entry', 'Rome', 'Roman', 'Dutch', 'Hendrick', 'Brederode', 'Margaret', 'Parma', 'Petition', 'Compromise', 'Inquisition', 'Seventeen', 'Provinces', 'Virginia', 'Pocahontas', 'English', 'John', 'Rolfe', 'Mayflower', 'Plymouth', 'Massachusetts', 'England', 'United', 'States', 'President', 'George', 'Washington', 'Basel', 'France']
# ['International', 'System', 'Units', 'Established', 'General', 'Conference', 'Weights', 'Measures', 'seven', 'Twenty', 'Planck', 'Boltzmann', 'Avogadro', 'Prior', 'Prototype', 'Metre', 'Convention', 'Introduction', 'United', 'States', 'Canada', 'Kingdom', 'three', 'Nevertheless', 'Imperial', 'CGPM', 'Consultative', 'Committee', 'Bureau', 'Overview', '80000', "'kilo", '1024.', '299792458', 'BIPM', 'CIPM']
# ['June', 'Quan', 'Eastern', 'Saint', 'Sabas', 'Battle', 'Trapani', 'Venetians', 'Mocl', 'Emirate', 'Granada', 'Kingdom', 'Castile', 'Flemish', 'Athis', 'Orge', 'First', 'Bannockburn', 'Henry', 'VIII', 'England', 'Francis', 'France', 'Treaty', 'Closer', 'Amity', 'Charles', 'Holy', 'Roman', 'Emperor', 'Dragut', 'Ottoman', 'Great', 'Siege', 'Malta', 'Action', 'Faial', 'Azores', 'Cinco', 'Chagas', 'English', 'Hudson', 'seven', 'William', 'Penn', 'Lenni', 'Lenape', 'Indians']
# ['Djibouti', 'Republic', 'Horn', 'Africa', 'Somalia', 'Ethiopia', 'Eritrea', 'Gulf', 'Aden', '23,200', 'Somaliland', 'Land', 'Punt', 'Nearby', 'Zeila', 'Adal', 'Ifat', 'Sultanates', 'Somali', 'Dire', 'Dawa', 'Ogaden', 'Territory', 'Afars', 'Issas', 'United', 'Nations', '1990s', '920,000', 'Arabic', 'Afar', 'Islam', 'thousand', 'Somalis', 'Cushitic', 'Afroasiatic', 'Ocean', 'Intergovernmental', 'Authority', 'Development', 'City', 'Yibuuti', 'Jabuuti', 'Tehuti', 'Thoth', 'Moon']
# ['September', 'Battle', 'Marathon', 'Athenians', 'Greece', 'Xiaowudi', 'Jianwendi', 'Emperor', 'Eastern', 'Simon', 'Montfort', 'Earl', 'Leicester', 'Peter', 'Aragon', 'Muret', 'Portop', 'James', 'Santa', 'Majorca', 'First', 'Siege', 'Gibraltar', 'Reconquista', 'Kingdom', 'Castile', 'Emirate', 'Granada', 'Henry', 'Hudson', 'River', 'Halve', 'Maen', 'Valletta', 'Malta', 'Austro', 'Ottoman', 'Vienna', 'Empire', 'Sultanate', 'Sulu', 'Balambangan', 'Island', 'East', 'India', 'Company', 'North']
# ['Oklahoma', 'Choctaw', 'Oklahumma', 'Cherokee', 'Okalahoma', 'South', 'Central', 'United', 'States', 'Texas', 'Kansas', 'Missouri', 'Arkansas', 'Mexico', 'Colorado', 'Upland', '28th', 'Oklahomans', 'City', 'Sooner', 'State', 'Territory', 'Appropriations', 'American', '46th', 'November', 'Great', 'Plains', 'Cross', 'Timbers', 'Interior', 'Highlands', 'three', 'Historically', 'Americans', 'Mississippi', 'River', 'five', 'Oklahoma.A', 'Tulsa', 'Etymology', 'Nation', 'Chief', 'Allen', 'Wright', 'Indian', 'Superintendent']
# ['February', 'Alaric', 'Visigoths', 'Breviary', 'Roman', 'Battle', 'Heath', 'King', 'Louis', 'France', 'Norse', 'Great', 'Heathen', 'Army', 'Saxony', 'Translatio', 'Pope', 'John', 'Otto', 'Holy', 'Emperor', 'Conrad', 'Burgundy', 'Lincoln', 'Stephen', 'England', 'Empress', 'Matilda', 'Terra', 'Mariana', 'Latvia', 'Estonia', 'Nine', 'Torda', 'Wars', 'Mortimer', 'Cross', 'Owen', 'Tudor', 'Spaniard', 'Pedro', 'Mendoza', 'Buenos', 'Aires', 'Argentina', 'Scotland', 'Three', 'Kingdoms', 'Inverlochy']
# ['1890s', '1880s', 'Thomas', 'Edison', 'George', 'Westinghouse', 'Electric', 'Light', 'Company', 'June', 'Harold', 'Brown', 'York', 'Both', 'Thomson', 'Houston', 'City', 'General', 'three', 'World', 'Niagara', 'Falls', 'Brush', 'December', 'Broadway', '3,500', 'Illuminating', 'United', 'States', 'Europe', 'Alternating', 'Guillaume', 'Duchenne', 'Gramme', 'Ganz', 'Works', 'Ziani', 'Ferranti', 'Lucien', 'Gaulard', 'Galileo', 'Ferraris', 'Pavel', 'Yablochkov', 'John', 'Dixon', 'Gibbs', 'Z.B.D']
# ['Harry', 'Bates', 'Royal', 'Academy', 'A.R.A', 'Workers', 'Guild', 'Sculpture', 'Biography', 'April', 'Stevenage', 'Hertfordshire', 'Farmer', 'Brindley', 'London', 'South', 'School', 'Technical', 'Jules', 'Dalou', 'Kensington', 'Socrates', 'People', 'Agora', 'Paris', 'Rodin', 'three', 'Chantrey', 'Bequest', 'Britain.Bates', 'Britain', 'Aeneas', 'Homer', 'Psyche', 'Rhodope', 'Hounds', 'Leash', 'Pandora', 'Summer', 'Exhibition', 'Bequest.One', 'Queen', 'Victoria', 'Albert', 'Square', 'Dundee', 'January', 'Hall', 'Road']
# ['Antonio', 'Santi', 'Giuseppe', 'Meucci', 'Garibaldi', 'Italy', 'Staten', 'Island', 'York', 'U.S.', 'Patent', 'Office', 'Alexander', 'Graham', 'Bell', 'Ministry', 'Cultural', 'Heritage', 'Activities', 'Inventore', 'House', 'Representatives', 'Senate', 'Serragli', 'Frediano', 'Florence', 'First', 'French', 'Empire', 'April', 'nine', 'Amatis', 'Domenica', 'Pepi', 'Four', 'November', 'Academy', 'Fine', 'Arts', 'Florentine', 'Marie', 'Anna', 'Saxony', 'Leopold', 'Grand', 'Duke']
# ['Columbia', 'College', 'University', 'Morningside', 'Heights', 'Manhattan', 'York', 'City', 'Church', 'England', 'King', 'George', 'Great', 'Britain', 'United', 'States', 'U.S.', 'News', 'World', 'Report', '2021', 'Core', 'Curriculum', 'History', 'Province', 'Trinity', 'Wall', 'Street', 'Samuel', 'Johnson', 'Latin', 'Park', 'Place', 'Hall', 'Bard', 'Physicians', 'Surgeons', 'Doctor', 'Medicine', 'America', 'Revolutionary', 'Alexander', 'Hamilton', 'General', 'Washington', 'Federalist', 'Papers']
# ['Nikola', 'Tesla', 'American', 'Empire', '1870s', '1880s', 'Continental', 'Edison', 'United', 'States', 'Machine', 'Works', 'York', 'City', 'Westinghouse', 'Electric', '1890s', 'Colorado', 'Springs', 'Wardenclyffe', 'Tower', '1910s', '1920s', 'January', 'General', 'Conference', 'Weights', 'Measures', '1990s', 'Smiljan', 'Military', 'Frontier', 'July', 'June', 'Milutin', 'Eastern', 'Orthodox', 'Church.Tesla', 'Mandi', 'Church', 'Serbia', 'Montenegro.Tesla', 'five', 'three', 'Milka', 'Angelina', 'Marica', 'Dane']
# ['World', 'Chess', 'Championship', 'Magnus', 'Carlsen', 'Norway', '2013.The', 'Wilhelm', 'Steinitz', 'Johannes', 'Zukertort', 'Alexander', 'Alekhine', 'FIDE', 'three', 'Garry', 'Kasparov', 'Champion', '2020', '2021', 'COVID', '2023', 'Viswanathan', 'Anand', '2022', 'Candidates', 'Tournament', 'Nepomniachtchi', 'Russia', 'Ding', 'Liren', 'China', 'Fischer', 'Random', 'History', 'Segura', 'Paolo', 'Leonardo', 'Cutri', 'Alessandro', 'Salvio', 'Gioachino', 'Greco', '18th', '19th']
# ['Sunday', 'Friday', 'Julian', '1888th', 'Common', 'Anno', 'Domini', '888th', '88th', '1880s', 'Germany', 'Three', 'Emperors', 'Roman', '2388', '2888', 'January', 'March', 'Lick', 'Observatory', 'California', 'Schoolhouse', 'Blizzard', 'Dakota', 'Territory', 'Montana', 'Minnesota', 'Nebraska', 'Kansas', 'Texas', 'National', 'Geographic', 'Society', 'Washington', 'D.C.', 'Amateur', 'Athletic', 'Union', 'William', 'Buckingham', 'Curtis', 'United', 'States', 'Lawn', 'Tennis', 'Association', 'England', 'February']
# ['John', 'Napier', 'Merchiston', 'Marvellous', 'Laird', 'Ioannes', 'Neper', 'Tower', 'Edinburgh', 'University', 'Cuthbert', 'Life', 'Archibald', 'Castle', 'Janet', 'Bothwell', 'Francis', 'Adam', 'Bishop', 'Orkney', 'Salvator', 'College', 'Andrews', 'Reformation', 'Protestants', 'Scotland', 'mainland', 'Europe', 'December', 'France', 'Flanders', 'Greek', 'Paris', 'Geneva', 'Gartness', 'Borthwick', 'Close', 'Royal', 'Mile', 'June', 'Secret', 'Giles', 'Parliament', 'House', "Cuthbert's.Many", 'Mirifici', 'Logarithmorum', 'Canonis', 'Descriptio']
# ['Kansas', 'City', 'Missouri', '2020', '508,090', '36th', 'United', 'States', 'metropolitan', '2,392,035', 'Jackson', 'County', 'Clay', 'Cass', 'Platte', '1830s', 'River', 'June', 'Territory', 'Downtown', 'Rivers', '319.03', '23rd', 'Satellite', 'Independence', 'Blue', 'Springs', 'Summit', 'Overland', 'Park', 'Olathe', 'Lenexa', 'Market', 'District', '18th', 'Vine', 'Country', 'Club', 'Plaza', 'Vaudevillian', 'Orpheum', '1920s', 'Chiefs', 'Royals', 'History', 'March', 'Antioch', 'Christian']
# ['Benjamin', 'Garver', 'Lamme', 'Westinghouse', 'Nikola', 'Tesla', 'Niagara', 'Falls', 'Manhattan', 'Elevated', 'Railway', 'York', 'City', 'Biography', 'Springfield', 'Ohio', 'January', 'Olive', 'Branch', 'High', 'School', 'Carlisle', 'State', 'University', 'Philadelphia', 'Natural', 'Company', 'Pittsburgh', 'Electric', 'Charles', 'Scott', 'eight', 'Gyroscopic', 'Rotary', 'Converter', 'Type', 'Induction', 'Motor', '5000', 'Adams', 'Power', 'Plant', 'Bertha', 'Feicht', 'Operation', 'Buffalo', '1896.Lamme', 'Exposition', 'Chicago']
# ['July', 'Siege', 'Jerusalem', 'Vespasian', 'Fortress', 'Antonia', 'Temple', 'Mount', 'Roman', 'Zealots', 'Kardam', 'Bulgaria', 'Byzantine', 'Emperor', 'Constantine', 'Battle', 'Marcellae', 'Rollo', 'Chartres', 'Richard', 'England', 'Duke', 'Normandy', 'Germano', 'Holy', 'Frederick', 'Pope', 'Gregory', 'Dominican', 'Guala', 'Kellistown', 'English', 'Roger', 'Mortimer', 'Earl', 'March', "O'Byrnes", "O'Tooles", 'Murchadha', 'Caomh', 'Chieftain', 'Leinster', 'Ottoman', 'Timurid', 'Ankara', 'Timur', 'Empire', 'Bayezid']
# ['June', 'Zhongdu', 'Jurchen', 'Emperor', 'Xuanzong', 'Mongols', 'Genghis', 'Khan', 'Battle', 'Alfonso', 'Castile', 'Residents', 'Riga', 'Grand', 'Duchy', 'Lithuania', 'Order', 'Turaida', 'John', 'Scotch', 'Anne', 'Boleyn', 'Queen', 'England', 'Charles', 'Ottomans', 'Tunis', 'Conquest', 'Roundheads', 'Maidstone', 'English', 'Civil', 'Start', 'Sumuroy', 'Revolt', 'Northern', 'Samar', 'Agustin', 'Dover', 'Louis', 'France', 'Secret', 'Treaty', 'Third', 'Anglo', 'Dutch', 'Baltic']
# ['December', 'Pepin', 'Herstal', 'Jupille', 'Theudoald', 'Plectrude', 'Kingdom', 'Lushan', 'Chancellor', 'Yang', 'Guozhong', 'Yanjing', 'Rebellion', 'Tang', 'China', 'Hundred', 'Years', 'Henry', 'England', 'King', 'France', 'Notre', 'Dame', 'Paris', 'Vasco', 'Gama', 'Great', 'Fish', 'River', 'Africa', 'Bartolomeu', 'Dias', 'Portugal', '8.5Mw', 'Valdivia', 'Chile', 'Year', 'Battle', 'Noryang', 'Seven', 'Korean', 'Interregnum', 'Oliver', 'Cromwell', 'Lord', 'Protector', 'Commonwealth', 'Scotland', 'Ireland', 'Convention']
# ['United', 'States', 'Incumbents', 'Government', 'President', 'William', 'McKinley', 'Vice', 'Garret', 'Hobart', 'Chief', 'Justice', 'Melville', 'Fuller', 'Speaker', 'House', 'Representatives', 'Thomas', 'Brackett', 'Reed', 'David', 'Henderson', 'Congress', '55th', '56th', 'January', 'Queens', 'Staten', 'Island', 'York', 'City', 'Kappa', 'Epsilon', 'Illinois', 'Wesleyan', 'University', 'Bloomington', 'Wake', 'February', 'American', 'Manila', 'Spain', 'Senate', 'U.S.', 'Philippines', 'Samoa', 'Guam', 'Puerto']
# ['June', 'Battle', 'Flavius', 'Aetius', 'Attila', 'Romans', 'First', 'Genpei', 'Japan', 'Thirty', 'Years', 'Sack', 'Baltimore', 'Tarhoncu', 'Ahmed', 'Pasha', 'Grand', 'Vizier', 'Ottoman', 'Empire', 'Monmouth', 'Rebellion', 'James', 'Scott', 'Duke', 'King', 'England', 'Bridgwater', 'Black', 'Hole', 'Calcutta', 'U.S.', 'Congress', 'Seal', 'United', 'States', 'Oliver', 'Ellsworth', 'Federal', 'Convention', 'Deputies', 'Third', 'Estate', 'Tennis', 'Court', 'Oath', 'Louis']
# ['Edison', 'Machine', 'Works', '1880s', 'Thomas', 'York', 'City', 'History', 'Menlo', 'Park', 'Etna', 'Iron', 'Goerck', 'Street', 'Lower', 'Manhattan', 'Charles', 'Batchelor', 'Dean', 'Pearl', 'Station', 'John', 'Kruesi', 'Samuel', 'Insull', 'Electric', 'Tube', 'Company', 'Shafting', 'Manufacturing', 'Schenectady', 'McQueen', 'Locomotive', 'General', 'Thomson', 'Houston', 'Lynn', 'Massachusetts', 'Justus', 'Entz', 'Reginald', 'Fessenden', 'Kunihiko', 'Iwadare', 'Emil', 'Kolben', 'Lieb', 'Nikola', 'Tesla']
# ['Rome', 'Renaissance', 'Siege', 'Cuzco', 'Incan', 'Spanish', 'King', 'Henry', 'VIII', 'English', 'Bibles', 'Great', 'Bible', 'Francis', 'Xavier', 'India', 'Dutch', 'Coevorden', 'Restoration', 'Army', 'Richard', 'Cromwell', 'Lord', 'Protector', 'Commonwealth', 'Rump', 'Parliament', 'Louis', 'France', 'Palace', 'Versailles', 'Battle', 'Prague', 'Seven', 'Years', 'Konbaung', 'Hanthawaddy', 'Burmese', 'Civil', 'Christopher', 'Smart', 'Luke', 'Hospital', 'Lunatics', 'London']
# ['Robert', 'France', 'Henry', 'King', 'Franks', 'Siege', 'Nicaea', 'First', 'Crusade', 'Battle', 'Lewes', 'England', 'Mise', 'Simon', 'Montfort', 'Agnadello', 'Italy', 'Republic', 'Venice', 'James', 'Fort', 'Jamestown', 'Virginia', 'Americas', 'Protestant', 'Union', 'Catholic', 'Church', 'zealot', 'Fran', 'Ravaillac', 'Louis', 'XIII', 'Four', 'Admiral', 'George', 'Anson', 'Cape', 'Finisterre', 'Edward', 'Jenner', 'United', 'States', 'Congress', 'Philadelphia', 'Washington']
# ['Sunday', 'Friday', 'Julian', '1888th', 'Common', 'Anno', 'Domini', '888th', '88th', '1880s', 'Germany', 'Three', 'Emperors', 'Roman', '2388', '2888', 'January', 'March', 'Lick', 'Observatory', 'California', 'Schoolhouse', 'Blizzard', 'Dakota', 'Territory', 'Montana', 'Minnesota', 'Nebraska', 'Kansas', 'Texas', 'National', 'Geographic', 'Society', 'Washington', 'D.C.', 'Amateur', 'Athletic', 'Union', 'William', 'Buckingham', 'Curtis', 'United', 'States', 'Lawn', 'Tennis', 'Association', 'England', 'February']
# ['June', 'Battle', 'Flavius', 'Aetius', 'Attila', 'Romans', 'First', 'Genpei', 'Japan', 'Thirty', 'Years', 'Sack', 'Baltimore', 'Tarhoncu', 'Ahmed', 'Pasha', 'Grand', 'Vizier', 'Ottoman', 'Empire', 'Monmouth', 'Rebellion', 'James', 'Scott', 'Duke', 'King', 'England', 'Bridgwater', 'Black', 'Hole', 'Calcutta', 'U.S.', 'Congress', 'Seal', 'United', 'States', 'Oliver', 'Ellsworth', 'Federal', 'Convention', 'Deputies', 'Third', 'Estate', 'Tennis', 'Court', 'Oath', 'Louis']
# ['Sweden', 'Kingdom', 'Northern', 'Europe', 'Scandinavia', 'Norway', 'Finland', 'Denmark', '450,295', 'European', 'Union', 'Stockholm', '10.5', 'million', '25.5', 'Swedes', 'Scandes', 'Baltic', 'Snow', 'Germanic', 'Geats', 'Norsemen', 'Black', 'Death', 'Hanseatic', 'League', 'Kalmar', 'Thirty', 'Years', 'Protestant', 'Empire', 'Peninsula', '18th', '19th', 'Russia', 'Switzerland', 'U.S.', 'Cold', 'NATO', '2022', 'Summit', 'Madrid.Sweden', 'Riksdag', 'Nordic', '12th', 'January', 'Eurozone', 'United']
# ['Alexandra', 'Feodorovna', 'Princess', 'Alix', 'Hesse', 'Rhine', 'Empress', 'Russia', 'Emperor', 'Nicholas', 'November', 'March', 'Queen', 'Victoria', 'United', 'Kingdom', 'Alexei', 'Nikolaevich', 'Tsarevich', 'Grigori', 'Rasputin', 'Romanov', 'Bolshevik', 'Revolution', 'Orthodox', 'Church', 'Saint', 'Passion', 'Bearer', 'Appearance', 'Anna', 'Vyrubova', 'Baroness', 'Sophie', 'Buxhoeveden', 'Pierre', 'Gilliard', 'Tsarina', 'Imperial', 'Grand', 'Duke', 'Constantine', 'Constantinovich', 'Nadine', 'Wonar', 'Larsky', 'Wonlar', 'Marie', 'Bariatinsky']
# ['Cathedral', 'John', 'Divine', 'Episcopal', 'Diocese', 'York', 'Amsterdam', 'Avenue', 'Morningside', 'Heights', 'Manhattan', 'City', 'West', '110th', 'Street', '113th', 'Byzantine', 'Revival', 'Romanesque', 'Gothic', '121,000', 'Leake', 'Watts', 'Orphan', 'Asylum', 'Building', 'Faith', 'House', 'Choir', 'School', 'Deanery', 'Bishop', 'Landmarks', 'Preservation', 'Commission', 'History', 'Context', 'Site', 'Dutch', 'Bloomingdale', 'Insane', 'Columbia', 'University', '116th', 'State', 'Legislature', 'three', 'Road']
# ['June', 'Roman', 'Nepotianus', 'Constantinian', 'Rome', 'Byzantine', 'Philippicus', 'Opsikion', 'Thrace', 'Anastasios', 'five', 'First', 'Crusade', 'Crusaders', 'Antioch', 'Peter', 'Abelard', 'Treaty', 'Novgorod', 'Russia', 'Norway', 'Finnmark', 'Hernando', 'Soto', 'Florida', 'Spain', 'Battle', 'Sesimbra', 'Samuel', 'Champlain', 'Tadoussac', 'Quebec', 'France', 'West', 'India', 'Company', 'Netherland', 'Pope', 'Alexander', 'Fran', 'Laval', 'James', 'Stuart', 'Duke', 'York', 'Dutch', 'Lowestoft', 'Jack']
# ['January', 'December', 'Slavery', 'Europe', 'Americas', 'Industrial', 'Revolution', 'Countries', 'Rhineland', 'Northern', 'Italy', 'Northeastern', 'United', 'States', 'Second', 'Islamic', 'South', 'Asia', 'Southeast', 'Africa', 'Mughal', 'France', 'Napoleonic', 'Wars', 'Russia', 'Central', 'Caucasus', 'Ottomans', 'Westernization', 'Tanzimat', 'Middle', 'East', 'Balkans', 'North', 'Maratha', 'Sikh', 'India', 'Company', 'Rebellion', 'Crown', 'Britain', 'Canada', 'Australia', 'Britannica', 'Morse']
# ['Lasc', 'Catargiu', 'Catargi', 'November', 'April', 'March', 'Moldavia', 'Prince', 'Matei', 'Basarab', 'Biography', 'Born', 'Grigore', 'Ghica', 'Divan', 'Treaty', 'Paris', 'Wallachia', 'Conservatives', 'Domnitor', 'Alexandru', 'Ioan', 'Cuza', 'Opposition', 'Barbu', 'Bucharest', 'June', 'Carol', 'President', 'Council', 'Ministers', 'Rosetti', 'July', 'eight', 'Liberals', 'Interior', 'seven', 'Emanuel', 'Florescu', 'December', 'Chisholm', 'Hugh', 'Lascar', 'Encyclop', 'Britannica', 'Cambridge', 'University']
# ['Mihajlo', 'Idvorski', 'Pupin', 'Michael', 'United', 'States', 'National', 'Advisory', 'Committee', 'Aeronautics', 'March', 'NASA', 'Mathematical', 'Society', 'American', 'Physical', 'Pulitzer', 'Prize', 'Institute', 'Electrical', 'Engineers', 'York', 'Academy', 'Sciences', 'Radio', 'America', 'Association', 'Advancement', 'Science', 'Serbia', 'Kingdom', 'Serbs', 'Croats', 'Slovenes', 'Serb', 'October', 'Idvor', 'Banat', 'Military', 'Frontier', 'Empire', 'From', 'Immigrant', 'Inventor', 'Knowledge', 'Serbian', 'Orthodox', 'German', 'Perlez']
# ['Austria', 'Hungary', 'Austro', 'Hungarian', 'Empire', 'Dual', 'Monarchy', 'Central', 'Europe', 'Compromise', 'Prussian', 'First', 'World', 'House', 'Habsburg', '621,538', 'United', 'States', 'Germany', 'Kingdom', 'Empire.At', 'Cisleithania', 'Austrian', 'Croatia', 'Slavonia', 'Settlement', 'Bosnia', 'Herzegovina', 'Powers', 'Serbia', 'July', 'Villa', 'Giusti', 'November', 'Republic', 'West', 'Slavs', 'South', 'Czechoslovak', 'Second', 'Polish', 'Yugoslavia', 'Romania', 'Italy', 'Formation', 'Peninsula', 'Confederation', 'Prussia']
# ['Wednesday', 'Monday', 'Julian', '1890th', 'Common', 'Anno', 'Domini', '890th', '90th', '1890s', 'January', 'March', 'Kingdom', 'Italy', 'Eritrea', 'Horn', 'Africa', 'Michigan', 'Mackinaw', 'Black', 'River', 'Persia', 'Corsica', 'Alice', 'Sanger', 'White', 'House', 'Ultimatum', 'United', 'Portugal', 'Portuguese', 'Mozambique', 'Angola', 'Sleeping', 'Beauty', 'Tchaikovsky', 'Imperial', 'Mariinsky', 'Theatre', 'Petersburg', 'Russia', 'Mine', 'Workers', 'America', 'Nellie', 'February']
# ...
# ['Exposition', 'Universelle', 'Paris', 'France', 'October', 'eight', 'million', 'Eiffel', 'Tower', 'Organization', 'Storming', 'Bastille', 'Revolution', '61,722', 'five', 'Admission', 'Francs', '41,500,000', '49,500,000', 'Universal', 'Expositions', 'National', 'Andorra', 'Argentina', 'Bolivia', 'Chile', 'Costa', 'Rica', 'Dominican', 'Republic', 'Ecuador', 'United', 'States', 'Greece', 'Guatemala', 'Haiti', 'Hawaii', 'Honduras', 'India', 'Japan', 'Morocco', 'Mexico', 'Monaco', 'Nicaragua', 'Norway', 'Paraguay', 'Persia', 'Saint']
# ['Australia', 'Maritime', 'Southeast', 'Asia', '50,000', '65,000', 'Antarctic', 'Tasmania', 'Bass', 'Strait', 'Torres', 'Islanders', 'Papua', 'Guinea', '2,500', 'Cape', 'York', 'Peninsula', 'Europeans', 'Dutch', 'Willem', 'Janszoon', 'Later', 'Twenty', 'nine', 'Holland', 'Macassan', 'Lieutenant', 'James', 'Cook', 'Great', 'Britain', 'London', 'Botany', 'First', 'Fleet', 'British', 'January', 'Gold', 'Transportation', 'Empire', 'Commonwealth', 'United', 'States', 'Imperial', 'Japan']
# ['Leicester', 'LEST', 'Leicestershire', 'East', 'Midlands', 'England', 'River', 'Soar', 'National', 'Forest', 'Birmingham', 'Coventry', 'Nottingham', 'Peterborough', 'City', '348,300', '18,500', '329,839', '11th', '13th', 'United', 'Kingdom.Leicester', 'Midland', 'Main', 'Line', 'London', 'Stansted', 'Airport', 'Tigers', 'English', 'Legorensis', 'Anglo', 'Saxon', 'Chronicle', 'Ligera', 'Domesday', 'Book', 'Ledecestre.The', 'Ligore', 'Ligor', 'Brittonic', '.The', 'Latin', 'History', 'Britons', 'Cair']
# ['Stephanus', 'Johannes', 'Paulus', 'Kruger', 'October', 'July', '19th', 'South', 'Africa', 'President', 'African', 'Republic', 'Paul', 'Boer', 'Transvaal', 'Orange', 'Free', 'State', 'Britain', 'Second', 'Afrikanerdom', 'Cape', 'Colony', 'Great', 'Trek', 'Bible', 'Voortrekker', 'Andries', 'Pretorius', 'Sand', 'River', 'Convention', 'Commandant', 'General', 'Thomas', 'Fran', 'Burgers', 'Vice', 'March', 'three', 'London', 'Boers', 'First', 'Witwatersrand', 'Gold', 'Rush', 'Jameson']
# ['February', 'Galeazzo', 'Santa', 'Sophie', 'Heiligen', 'Geist', 'Spital', 'Vienna', 'John', 'Fastolf', 'Battle', 'Herrings', 'Isabella', 'Islam', 'Crown', 'Castile', 'Muslim', 'Christianity', 'Vasco', 'Gama', 'Lisbon', 'Portugal', 'India', 'Santiago', 'Chile', 'Pedro', 'Valdivia', 'Korea', '3,000', 'Joseon', 'Kwon', '30,000', 'Siege', 'Haengju', 'Convention', 'Parliament', 'France', 'James', 'Roman', 'Catholic', 'British', 'Georgia', 'Englishman', 'Oglethorpe', '13th', 'Thirteen', 'Colonies']
# ['August', 'Pope', 'Eugene', 'Martinus', 'Battle', 'Lechfeld', 'Otto', 'Holy', 'Roman', 'Emperor', 'Magyars', 'Magyar', 'West', 'Maldon', 'English', 'Byrhtnoth', 'Ealdorman', 'Essex', 'Azaz', 'Byzantine', 'Romanos', 'Argyros', 'Mirdasid', 'Aleppo', 'Yekuno', 'Amlak', 'Ethiopia', 'Solomonic', 'Zagwe', 'Athenry', 'Bruce', 'Ireland', 'Jaume', 'Ferrer', 'Majorca', 'River', 'Gold', 'Senegal', 'Saint', 'Mathieu', 'League', 'Cambrai', 'Breton', 'Cordeli', 'Regent', 'Ferdinand', 'Magellan', 'five', 'Seville']
# ['Alfred', 'Dreyfus', 'Europe', 'Born', 'Mulhouse', 'Alsace', 'nine', 'Rapha', 'Jeannette', 'Jewish', 'Franco', 'Prussian', 'Lorraine', 'Germany', 'Basel', 'Switzerland', 'Paris', 'October', 'Polytechnique', 'Fontainebleau', 'Thirty', 'Artillery', 'Regiment', 'Mans', 'First', 'Cavalry', 'Division', 'Bourges', 'April', 'Lucie', 'Hadamard', 'Pierre', 'Jeanne', 'Three', 'Guerre', 'College', 'Army', 'Staff', 'December', 'General', 'Bonnefond', 'Jews', 'Lieutenant', 'Picard', 'Learning']
# ['December', 'Emperor', 'Constantinople', 'Roman', 'Abbasid', 'Mutawakkil', 'Turkish', 'Muntasir', 'Start', 'Anarchy', 'Samarra', 'Byzantine', 'Nikephoros', 'Phokas', 'Theophano', 'John', 'Tzimiskes', 'Michael', 'Empress', 'Byzantium', 'Eastern', 'Empire', 'Battle', 'Orewin', 'Bridge', 'Llywelyn', 'Gruffudd', 'Wales', 'Cilmeri', 'Builth', 'Wells', 'Charles', 'Emmanuel', 'Duke', 'Savoy', 'Philip', 'Spain', 'Geneva', 'Root', 'Branch', '15,000', 'Long', 'Parliament', 'Antonio', 'Rafael', 'Lake']
# ['December', 'Battle', 'Nineveh', 'Byzantine', 'Emperor', 'Heraclius', 'Khosrau', 'General', 'Rhahzadh', 'Maria', 'Enghien', 'Argos', 'Nauplia', 'Republic', 'Venice', 'Pennsylvania', 'Constitution', 'American', 'Civil', 'Cairo', 'Yazoo', 'River', 'Oaks', 'England', 'Joseph', 'Rainey', 'South', 'Carolina', 'U.S.', 'Guglielmo', 'Marconi', 'Signal', 'Hill', 'John', 'Newfoundland', 'Shikai', 'Empire', 'China', 'Father', 'Edward', 'Flanagan', 'Boys', 'Town', 'Lebensborn', 'Project', 'Heinrich', 'Himmler', 'Second']
# ['United', 'States', '5,280', 'English', '1,760', 'Commonwealth', '1,609.344', 'Roman', 'Romans', '5,000', 'Elizabethan', 'England', 'Empire', 'Geological', 'Survey', '2022', 'International', 'System', 'Units', 'Liberia', 'Kingdom', 'million', 'Middle', 'Germanic', 'Parliament', 'Foreign', 'Antonine', 'Itinerary', 'Abbreviation', 'National', 'Institute', 'Standards', 'Technology', 'Historical', '1,000', 'Well', 'Agrippa', 'Imperial', '1,618', 'Hellenic', 'Byzantine', 'Milion', 'Mese', 'Hagia', 'Sophia', 'Europe', 'Forum']
# ['United', 'States', 'America', 'U.S.', 'five', 'nine', 'Great', 'Britain', 'Nicknames', 'Stars', 'Stripes', 'Glory', 'Star', 'Spangled', 'Banner', 'History', 'July', 'Eisenhower', 'August', 'Grand', 'Union', 'Flag', 'Colors', 'Jack', 'December', 'Continental', 'Navy', 'Lieutenant', 'John', 'Paul', 'Jones', 'Captain', 'Esek', 'Hopkin', 'Alfred', 'Delaware', 'River', 'June', 'Declaration', 'Independence', 'Congress', 'American', 'George', 'Henry', 'Preble', 'Flag.The', 'East', 'India']
# ['July', 'Rome', 'Roman', 'Emperor', 'Anthemius', 'Peter', 'Basilica', 'Byzantine', 'Michael', 'Armenian', 'Treaty', 'Saint', 'Clair', 'Epte', 'Charles', 'Simple', 'Rollo', 'Normandy', 'Baldwin', 'King', 'Jerusalem', 'Raymond', 'Count', 'Tripoli', 'William', 'Tyre', 'Battle', 'Golden', 'Spurs', 'France', 'Luxembourg', 'Bohemia', 'Romans', 'Zheng', 'Ottoman', 'Interregnum', 'Musa', 'Edirne', 'Giuliano', 'Rovere', 'North', 'Atlantic', 'Ocean', 'Northwest', 'Passage', 'Martin', 'Frobisher', 'Greenland']
# ['January', 'December', 'Slavery', 'Europe', 'Americas', 'Industrial', 'Revolution', 'Countries', 'Rhineland', 'Northern', 'Italy', 'Northeastern', 'United', 'States', 'Second', 'Islamic', 'South', 'Asia', 'Southeast', 'Africa', 'Mughal', 'France', 'Napoleonic', 'Wars', 'Russia', 'Central', 'Caucasus', 'Ottomans', 'Westernization', 'Tanzimat', 'Middle', 'East', 'Balkans', 'North', 'Maratha', 'Sikh', 'India', 'Company', 'Rebellion', 'Crown', 'Britain', 'Canada', 'Australia', 'Britannica', 'Morse']
# ['February', 'Alaric', 'Visigoths', 'Breviary', 'Roman', 'Battle', 'Heath', 'King', 'Louis', 'France', 'Norse', 'Great', 'Heathen', 'Army', 'Saxony', 'Translatio', 'Pope', 'John', 'Otto', 'Holy', 'Emperor', 'Conrad', 'Burgundy', 'Lincoln', 'Stephen', 'England', 'Empress', 'Matilda', 'Terra', 'Mariana', 'Latvia', 'Estonia', 'Nine', 'Torda', 'Wars', 'Mortimer', 'Cross', 'Owen', 'Tudor', 'Spaniard', 'Pedro', 'Mendoza', 'Buenos', 'Aires', 'Argentina', 'Scotland', 'Three', 'Kingdoms', 'Inverlochy']
# ['Sunderland', 'Northern', 'England', 'City', 'Metropolitan', 'Tyne', 'Wear', 'Historic', 'County', 'Durham', 'North', 'East', 'Combined', 'Authority', 'Newcastle', 'River', 'Mackems', '1980s', 'Jamie', 'three', 'Monkwearmouth', 'King', 'Ecgfrith', 'Northumbria', 'Benedict', 'Biscop', 'Jarrow', 'Abbey', 'Bishopwearmouth', 'Toponymy', 'Bede', 'History', 'Stone', 'Peter', 'Church', 'Neolithic', 'Hastings', 'Hill', 'Evidence', 'Roman', 'Empire', 'Brigantes', 'Vaux', 'Brewery', 'March', '2021', 'Hylton']
# ['August', 'Pope', 'Eugene', 'Martinus', 'Battle', 'Lechfeld', 'Otto', 'Holy', 'Roman', 'Emperor', 'Magyars', 'Magyar', 'West', 'Maldon', 'English', 'Byrhtnoth', 'Ealdorman', 'Essex', 'Azaz', 'Byzantine', 'Romanos', 'Argyros', 'Mirdasid', 'Aleppo', 'Yekuno', 'Amlak', 'Ethiopia', 'Solomonic', 'Zagwe', 'Athenry', 'Bruce', 'Ireland', 'Jaume', 'Ferrer', 'Majorca', 'River', 'Gold', 'Senegal', 'Saint', 'Mathieu', 'League', 'Cambrai', 'Breton', 'Cordeli', 'Regent', 'Ferdinand', 'Magellan', 'five', 'Seville']
# ['June', 'King', 'Charles', 'Roquefort', 'Soulzon', 'Paul', 'London', 'Siege', 'Osaka', 'Tokugawa', 'Ieyasu', 'Castle', 'Japan', 'Battle', 'Hohenfriedberg', 'Frederick', 'Great', 'Prince', 'Alexander', 'Lorraine', 'Succession', 'Upheaval', 'England', 'Nova', 'Scotia', 'Canada', 'Acadians', 'Montgolfier', 'four', '1,500', 'Captain', 'George', 'Vancouver', 'Puget', 'Sound', 'Kingdom', 'Britain', 'Emmanuel', 'Sardinia', 'Victor', 'Louisiana', 'U.S.', 'Territory', 'Missouri', 'General', 'Lafayette', 'Revolutionary', 'Square', 'Buffalo']
# ['Servius', 'Tullius', 'Rome', 'Etruscans', 'First', 'Halley', 'Comet', 'Alfonso', 'Castile', 'Toledo', 'Spain', 'Moors', 'Henry', 'Navigator', 'Order', 'Christ', 'Diet', 'Worms', 'Charles', 'Holy', 'Roman', 'Emperor', 'Edict', 'Martin', 'Luther', 'Sangui', 'Manchus', 'Great', 'Wall', 'China', 'Shanhaiguan', 'Beijing', 'Richard', 'Cromwell', 'Lord', 'Protector', 'England', 'Long', 'Parliament', 'Commonwealth', 'Dover', 'Convention', 'Scotland', 'Ireland', 'Restoration', 'Pennsylvania', 'Maryland', 'Conojocular', 'United']
# ['Sunday', 'Friday', 'Julian', '1899th', 'Common', 'Anno', 'Domini', '899th', '99th', '10th', '1890s', 'January', 'Cuba', 'Americas', 'Staten', 'Island', 'York', 'City', 'Bolivia', 'Puerto', 'Alonso', 'Republic', 'Acre', 'Jakarta', 'Kota', 'Anyer', 'Kidul', 'Java', 'Batavia', 'Zuid', 'Tangerang', 'Hungarian', 'Prime', 'Minister', 'Dezs', 'U.S.', 'President', 'William', 'McKinley', 'December', 'Philippines', 'United', 'States', 'Manila', 'General', 'Elwell', 'Otis']
# ['Allis', 'Chalmers', 'U.S.', 'Company', 'Edward', 'Fraser', 'Gates', 'Iron', 'Works', 'Dickson', 'Manufacturing', '1980s', '1990s', 'Energy', 'AGCO', 'History', 'Overview', 'Author', 'Randy', 'Leffingwell', 'Metal', 'Financial', 'Former', 'Walter', 'Buescher', '1800s', 'Reliance', 'Milwaukee', 'Wisconsin', 'James', 'Decker', 'Charles', 'Seville', 'George', 'Hinkley', 'William', 'Gray', 'Edwin', 'Reynolds', 'Corliss', 'Steam', 'Engine', 'America', 'Thomas', 'Chicago', 'Illinois', 'Canada', 'Scranton', 'Pennsylvania']
# ['Charles', 'Babbage', 'Josip', 'Belu', 'Operation', 'Exposition', 'Universelle', 'Paris', 'Otto', 'Schultze', 'October', 'Mechanical', 'Volkswagen', 'Beetle', 'Chronometric', 'zero', 'Electronic', 'Bicycle', 'Typical', 'Error', 'Vehicle', 'Percentage', 'Diameter', '25.4', '70R14', '614.6', '50R15', '576.0', '1.067', '106.7', '12.8', 'International', 'United', 'Nations', 'Economic', 'Commission', 'Europe', 'Regulation', 'UNECE', 'Union', 'Conformity']
# ['Bank', 'London', 'England', 'Berenberg', 'Barings', 'Francis', 'Baring', 'million', 'Nick', 'Leeson', 'Singapore', 'John', 'Company', 'Exeter', 'Bremen', 'Germany', 'Cheapside', 'Mincing', 'Lane', 'North', 'America', 'Amsterdam', 'Hope', 'Devonshire', 'Square', 'Maine.In', 'Thomas', 'Charles', 'Wall', 'Louisiana', 'Purchase', 'United', 'States', 'Britain', 'France', 'Napoleon', '87.50', 'Alexander', 'Paris', 'Fran', 'Barb', 'Marbois', 'Public', 'Treasury', 'Henry', 'Brothers', 'three', 'Bishopsgate']
# ['Banca', 'Commerciale', 'Italiana', 'Italy', 'Cassa', 'Risparmio', 'Provincie', 'Lombarde', 'Banco', 'Ambroveneto', 'Intesa', 'January', 'Sanpaolo', 'Turin', 'History', 'Societ', 'Generale', 'Credito', 'Mobiliare', 'October', 'German', 'Bleichr', 'Deutsche', 'Bank', 'Dresdner', 'Giuseppe', 'Toeplitz', 'Varese', 'Istituto', 'Ricostruzione', 'Industriale', 'Roma', 'Italiano', 'Banking', 'Legnano', 'Popolare', 'Milano', 'International', 'World', 'Banque', 'Tunisienne', 'Comerciale', 'Italo', 'Brasiliano', 'Paolo', 'Svizzera']
# ['Nikola', 'Tesla', 'Many', 'United', 'States', 'Britain', 'Canada', 'U.S.', 'Patent', '334,823', 'Commutator', 'Dynamo', 'Electric', 'Machines', 'January', 'Drum', '335,786', 'February', '335,787', 'Automatic', '336,961', 'Regulator', 'March', 'Intermediate', '336,962', 'Auxiliary', 'Regulates', '350,954', 'October', 'Mechanical', '359,748', 'Improve', 'Facilitate', 'Reduce', 'Magnetic', 'Armature', 'Alternating', '381,968', 'Electro', 'Mode', 'Field', 'Magnet', 'Electrical', 'Economical', 'Transmission', 'Simple', 'Easier', 'Rotating']
# ['Boudreau', 'Paris', '1880s', 'William', 'Klein', 'Albert', 'Duclos', 'History', 'Moghol', 'January', 'Excelsior', 'Romualdo', 'Marenco', 'Wagner', 'Lohengrin', 'Ernest', 'Dyck', 'Devri', 'Charles', 'Lamoureux', 'Madame', 'Angot', 'Anna', 'Judic', 'Jeanne', 'Granier', 'Dupuis', 'four', 'Orph', 'Christian', 'Lecocq', 'Baba', 'Lyrique', 'October', 'Samson', 'Dalila', 'Talazac', 'Bloch', 'jolie', 'Engel', 'Grand', 'November', 'Daudet', 'Sapho', 'Malade', 'Charpentier', 'Saint']
# ['Imperial', 'Empire', 'Prussian', 'Kaiser', 'Wilhelm', 'Admiral', 'Alfred', 'Tirpitz', 'Thayer', 'Mahan', 'Britain', 'Royal', 'First', 'World', 'Battle', 'Jutland', 'Armistice', 'Seiner', 'Majest', 'Schiff', 'Coronel', 'hundred', 'Falkland', 'Islands', 'Great', 'Pommern', 'Germany', 'King', 'Prussia', 'Confederation', 'Kingdom', 'Article', 'Supreme', 'General', 'Infanterie', 'Albrecht', 'Stosch', 'Kiel', 'Baltic', 'Wilhelmshaven', 'North', 'Ministry', 'Admiralty', 'February']
# ['Futbol', 'Club', 'Barcelona', 'Catalonia', 'Spain', 'Swiss', 'English', 'German', 'Catalan', 'Joan', 'Gamper', 'UEFA', 'Liga', '2020', 'Athletic', 'Bilbao', 'Real', 'Madrid', 'Catalonism', 'Francisco', 'Franco', '2000s', '2010s', 'Football', 'October', 'Deportes', 'Gimnasio', 'November', 'Eleven', 'Walter', 'Wild', 'Luis', 'Bartomeu', 'Terradas', 'Otto', 'Kunzle', 'Maier', 'Enric', 'Ducal', 'Pere', 'Cabot', 'Josep', 'Llobet', 'John', 'Parsons', 'William']
# ['Boxer', 'Rebellion', 'Uprising', 'Insurrection', 'Movement', 'China', 'Qing', 'Society', 'Righteous', 'Harmonious', 'Fists', 'Boxers', 'English', 'Sino', 'Japanese', 'North', 'Christian', 'Northern', 'Yellow', 'River', 'Shandong', 'Plain', 'Christians', 'June', 'Beijing', 'Support', 'Legation', 'Quarter', 'Alliance', 'American', 'Austro', 'Hungarian', 'British', 'French', 'German', 'Italian', 'Dagu', 'Fort', 'Tianjin', 'Empress', 'Dowager', 'Cixi', 'Imperial', 'Decree', 'Prince', 'Manchu', 'General', 'Ronglu', 'Eight', 'Nation']
# ['Johann', 'Life', 'Lubjassaare', 'Wast', 'Viljandi', 'County', 'Fellin', 'Livonia', 'Petersburg', 'Johan', 'Imperial', 'Academy', 'Arts', 'Paris', 'Berlin', 'Germany', 'Netherlands', 'Belgium', 'Alps', 'Milan', 'Geneva', 'Florence', 'Rome', 'Christ', 'Cross', 'Grand', 'Duchess', 'Maria', 'Aleksandrovna', 'Czar', 'Alexander', 'Vienna', 'Nice', 'Carl', 'Robert', 'Jakobson', 'Society', 'Estonian', 'Literati', 'Miscellaneous', 'Eesti', 'Post', 'Woman', 'Children', 'Stream', 'Italian', '82.5', '53.5']
# ['Joseph', 'Maurice', 'Ravel', 'Impressionism', 'Claude', 'Debussy', '1920s', '1930s', 'France', 'Born', 'Paris', 'Conservatoire', 'Mussorgsky', 'eight', 'Gaspard', 'Daphnis', 'Chlo', 'Life', 'Basque', 'Ciboure', 'Biarritz', 'Pierre', 'Versoix', 'Franco', 'Swiss', 'Marie', 'Delouart', 'Madrid', '19th', 'Whirlwind', 'Death', 'Barnum', 'Bailey', 'Circus', '1903.Both', 'Roman', 'Catholics', 'three', 'Spanish', 'Roger', 'Nichols', 'seven', 'Henri', 'Ghys', 'Emmanuel', 'Chabrier', 'five', 'Charles']
# ['Paul', 'League', 'Patriots', 'Paris', 'Revue', 'Jean', 'Rebel', 'Fran', 'Juan', 'Strenner', 'Franco', 'Prussian', 'Battle', 'Sedan', 'Breslau', 'Antoine', 'Chanzy', 'Charles', 'Denis', 'Bourbaki', 'Switzerland', 'Commune', 'Nouveaux', 'Chants', "L'Hetman", 'Vive', 'France', 'Gounod', 'Moabite', 'Henri', 'Martin', 'Faure', 'Ligue', 'Germany', '182,000', 'March', 'Chamber', 'Deputies', 'Britain', 'General', 'Georges', 'Boulanger', 'Patriotes', 'Angoul', 'Dreyfusard', 'President', 'February', 'Gaud', 'Roget']

# %%
keys_dict = open('../data/keys_dict.csv', 'r')
keys_df = pd.read_csv(keys_dict) # read the csv file
keys_df = keys_df.drop(columns=['Unnamed: 0']) # drop the index column
# convert the dataframe to a dictionary
keys_dict = keys_df.to_dict('list')
keys_dict = {k: v for k, v in keys_dict.items() if v != ['nan']} # remove entries with no keys
keys_dict = {k: v for k, v in keys_dict.items() if v != ['']} # remove entries with no keys





#todo:ticket 0001 - add a function to reduce keywords to a max of 50.
# get the top most unique keywords for the entry as compared to the other entries
def find_unique_keys(row_keys,keys_dict):
    # given row_keys and keys_dict, return up to 50 keys that are either unique to the row (first priority) or most commonly occuring in the keys_dict (second priority)
    # row_keys is a list of keys for a single entry
    # keys_dict is a list of all keys for all entries
    # return a list of up to 50 keys
    # finding unique to row
    unique_keys = []
    for key in row_keys:
        # if the key is only found in this row, add it to the unique keys
        if keys_dict.count(key) == 1:
            unique_keys.append(key)
    # if there are more than 50 unique keys, return the first 50
    if len(unique_keys) > 50:
        return unique_keys[:50]
    # if there are less than 50 unique keys, find the most common keys in the keys_dict that are also in the row_keys
    else:
        # find the most common keys in the keys_dict that are also in the row_keys
        # get the count of each key in the keys_dict
        key_counts = {}
        for key in keys_dict:
            if key in key_counts:
                key_counts[key] += 1
            else:
                key_counts[key] = 1
        # sort the key_counts by value
        sorted_key_counts = sorted(key_counts.items(), key=lambda x: x[1], reverse=True)
        # add the top 50 keys to the unique_keys list
        for key in sorted_key_counts:
            if key[0] in row_keys and len(unique_keys) < 50:
                unique_keys.append(key[0])
        return unique_keys
    return unique_keys

# run this on each row of the keys_dict
