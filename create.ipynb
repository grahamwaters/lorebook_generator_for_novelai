# %%
import pandas as pd
# read in the csv file
df = pd.read_csv('paragraphs.csv')
df.head(100)
# Out:
#     Unnamed: 0                     0  \
# 0            0    ('Paris', 'Tesla')
# 1            1    ('Tesla', 'Paris')
# 2            2  ('Paris', 'hunting')
# 3            3  ('hunting', 'Paris')
# 4            4     ('Paris', '1883')
# ..         ...                   ...
# 95          95    ('Tesla', 'Paris')
# 96          96  ('Paris', 'hunting')
# 97          97  ('hunting', 'Paris')
# 98          98     ('Paris', '1883')
# 99          99     ('1883', 'Paris')
#
#                                                     1
# 0   Hedy Lamarr was an Austrian born American film...
# 1   Hedy Lamarr was an Austrian born American film...
# 2   Europe is a landmass conventionally considered...
# 3   Europe is a landmass conventionally considered...
# 4   This is a list of state leaders in the 19th ce...
# ..                                                ...
# 95  1856 was a leap year starting on Tuesday of th...
# 96  Helsinki hel SINK ee; Finnish: helsi ki ; Swed...
# ...
